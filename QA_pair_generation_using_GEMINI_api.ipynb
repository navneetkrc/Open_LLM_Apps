# %% [markdown]
# <a href="https://colab.research.google.com/github/navneetkrc/Open_LLM_Apps/blob/main/QA_pair_generation_using_GEMINI_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q PyMuPDF
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 15.3 MB/s eta 0:00:00

# %%
import google.generativeai as genai
from google.colab import userdata
apikey=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=apikey)

# %%
generated_text = """## Navigating Samsung Microwave Support: A Comprehensive Guide

Samsung microwaves are ubiquitous in modern kitchens, offering convenience and speed for cooking and reheating. However, like any appliance, they can occasionally encounter issues. Fortunately, Samsung provides extensive support documentation to help users troubleshoot problems and keep their microwaves running smoothly. This guide explores the various resources available and outlines common troubleshooting steps.

**Understanding the Importance of Support Documentation**

Before contacting customer support, consulting the available documentation can often resolve common issues quickly and efficiently. Samsung's support resources typically include:

*   **User Manuals:** These are essential guides provided with every new microwave. They contain detailed instructions on operation, safety precautions, cleaning procedures, and basic troubleshooting.
*   **Online Support Pages:** Samsung's website offers dedicated support pages for each microwave model. These pages often include FAQs, troubleshooting guides, how-to videos, software updates (if applicable), and downloadable manuals.
*   **Samsung Community Forums:** These forums provide a platform for users to connect with each other, share experiences, and find solutions to common problems. Samsung representatives may also participate in these forums.

**Common Microwave Issues and Troubleshooting Steps**

Here are some common problems encountered with Samsung microwaves and the steps users can take to resolve them, often found within the support documentation:

**1. Microwave Not Heating:**

*   **Power Supply:** The most basic check is to ensure the microwave is properly plugged into a functioning power outlet. Check the circuit breaker or fuse box to rule out power supply issues. Inspect the power cord for any visible damage.
*   **Door Interlock System:** Microwaves have safety interlocks that prevent operation when the door is open. Ensure the door is fully closed and that there are no obstructions preventing it from latching correctly. Check the door seals for cleanliness and integrity.
*   **Magnetron:** The magnetron generates the microwaves that heat food. If the above steps don't resolve the issue, the magnetron may be faulty. This usually requires professional repair.
*   **High-Voltage Diode and Capacitor:** These components are part of the high-voltage circuit that powers the magnetron. A faulty diode or capacitor can prevent heating. These components should only be inspected and repaired by qualified technicians due to the high voltages involved.
*   **Control Panel Issues:** A malfunctioning control panel might prevent the microwave from starting or heating. This could be due to a software glitch or a hardware problem.

**2. Microwave Not Turning On:**

*   **Power Supply:** As above, check the power outlet, circuit breaker, and power cord.
*   **Control Panel Lock:** Some microwaves have a control panel lock feature to prevent accidental operation. Check the user manual to see if this feature is enabled and how to disable it.
*   **Internal Fuse:** Some microwaves have internal fuses that protect the electronic components. If the microwave is completely unresponsive, an internal fuse may have blown. This requires professional repair.

**3. Arcing or Sparks Inside the Microwave:**

*   **Metal Objects:** Never place metal objects inside a microwave. This can cause arcing and sparks, which can damage the microwave and pose a fire hazard.
*   **Damaged Waveguide Cover:** The waveguide cover protects the magnetron from food splatters. If this cover is damaged, it can cause arcing. Replace the damaged cover.
*   **Food Debris:** Food debris inside the microwave can also cause arcing. Clean the interior thoroughly.

**4. Turntable Not Rotating:**

*   **Turntable Track:** Ensure the turntable is properly placed on the track. Check for any obstructions that might be preventing it from rotating.
*   **Turntable Motor:** If the turntable is properly placed and there are no obstructions, the turntable motor may be faulty.

**5. Error Codes Displayed:**

*   **Consult the User Manual:** When an error code is displayed, consult the user manual. It will provide a description of the error and suggested troubleshooting steps.
*   **Online Support:** Samsung's online support pages often have a database of error codes and their meanings.

**Utilizing Online Resources Effectively**

When using Samsung's online support resources, having the model number of your microwave is crucial. This information is usually found on a sticker inside the microwave door or on the back of the unit. With the model number, you can access specific information for your microwave, including:

*   **Downloadable User Manuals:** If you've misplaced your physical manual, you can download a digital copy from the website.
*   **Troubleshooting Guides:** These guides provide step-by-step instructions for resolving common problems.
*   **FAQs:** Frequently asked questions can often provide quick answers to common queries.
*   **How-to Videos:** Visual guides can be particularly helpful for tasks like cleaning or replacing parts.

**Contacting Samsung Support**

If the available documentation doesn't resolve the issue, contacting Samsung support is the next step. They can provide further assistance and, if necessary, arrange for repairs. When contacting support, be prepared to provide the following information:

*   **Model Number:** This allows the support representative to access specific information about your microwave.
*   **Serial Number:** This helps track your microwave's history.
*   **Description of the Problem:** Be as specific as possible when describing the issue you are experiencing.

By utilizing Samsung's comprehensive support documentation and following the troubleshooting steps outlined above, users can often resolve common microwave issues quickly and efficiently, minimizing downtime and maximizing the lifespan of their appliance. Remember to always prioritize safety and consult a qualified technician for any repairs involving high-voltage components or internal mechanisms.
"""

# %%
import google.generativeai as genai
content = generated_text

# apikey=userdata.get('GOOGLE_API_KEY')
# genai.configure(api_key=apikey)

model = genai.GenerativeModel('gemini-1.5-flash')
response = model.generate_content(f"generate question-answer pairs from content {content}")
print(response.text)
# Out:
# ## Samsung Microwave Support: Question-Answer Pairs
#
# Here are some question-answer pairs based on the provided text:
#
# **General Support:**
#
# Q: Where can I find support documentation for my Samsung microwave?
# A: You can find support documentation in the user manual (provided with the microwave), on Samsung's online support pages (search by model number), and on Samsung community forums.
#
# Q: Why is it important to consult support documentation before contacting customer support?
# A: Consulting the documentation often resolves common issues quickly and efficiently, saving time and potentially avoiding the need for a service call.
#
# Q: What information is crucial when using Samsung's online support resources?
# A:  Your microwave's model number is crucial to access specific information and troubleshooting guides.
#
#
# **Troubleshooting Specific Issues:**
#
# **Microwave Not Heating:**
#
# Q: My Samsung microwave isn't heating. What are the first things I should check?
# A: First, check if the microwave is plugged in properly, the circuit breaker isn't tripped, and the power cord isn't damaged.  Then, ensure the door is fully closed and the seals are clean and intact.
#
# Q: If the power supply and door interlock seem fine, what could be causing my microwave to not heat?
# A: A faulty magnetron, high-voltage diode, capacitor, or control panel issues could be the cause. These usually require professional repair.
#
# **Microwave Not Turning On:**
#
# Q: My Samsung microwave won't turn on. What should I check?
# A: Check the power supply (outlet, circuit breaker, power cord), and see if the control panel is locked.  An internal fuse might also be blown, requiring professional repair.
#
# **Arcing or Sparks:**
#
# Q: I'm seeing arcing or sparks inside my Samsung microwave. What could be causing this?
# A: This is likely due to metal objects inside the microwave, a damaged waveguide cover, or food debris.  Remove metal objects, replace a damaged waveguide cover, and clean the interior thoroughly.
#
# **Turntable Not Rotating:**
#
# Q: The turntable in my Samsung microwave isn't rotating. What's the problem?
# A: Check if the turntable is properly placed on its track and that there are no obstructions. If the problem persists, the turntable motor may be faulty.
#
# **Error Codes:**
#
# Q: My Samsung microwave is displaying an error code. How can I troubleshoot this?
# A: Consult your user manual or Samsung's online support pages for a list of error codes and their solutions.
#
# **Using Online Resources:**
#
# Q: I lost my user manual. Where can I find a copy?
# A: You can download a digital copy of your user manual from Samsung's website using your microwave's model number.
#
# **Contacting Samsung Support:**
#
# Q: What information should I have ready when contacting Samsung support?
# A: Have your microwave's model number, serial number, and a clear description of the problem ready.
#
#
# These question-answer pairs cover the key aspects of navigating Samsung microwave support as detailed in the provided text.

# %%
import google.generativeai as genai

# apikey=userdata.get('GOOGLE_API_KEY')  # You'll need to set your API key
# genai.configure(api_key=apikey)

content = generated_text

def generate_qa_pairs(text):
    """
    Generates question-answer pairs from a given text using a generative AI model.

    This method utilizes Google's Gemini model to extract potential questions and their corresponding
    answers directly from the provided text content. The goal is to create a set of informative
    Q&A pairs that accurately reflect the information within the text.

    Args:
        text: The input string containing the content from which to generate questions and answers.

    Returns:
        str: The generated question-answer pairs formatted as a string.
    """
    model = genai.GenerativeModel('gemini-1.5-flash')
    prompt = f"Generate question-answer pairs based on the following text:\n\n{text}"
    response = model.generate_content(prompt)
    return response.text

def generate_structured_qa(text):
    """
    Generates more structured and detailed question-answer pairs from a given text.

    This method aims to create question-answer pairs that are more focused and insightful.
    It instructs the AI model to specifically identify problems and their corresponding solutions
    within the text, presenting them in a clear and structured format. This approach leads to
    more targeted and helpful Q&A compared to a general extraction.

    Args:
        text: The input string containing the content to analyze.

    Returns:
        str: The generated question-answer pairs, often including more detailed answers and
             potential follow-up information, formatted as a string.
    """
    model = genai.GenerativeModel('gemini-1.5-flash')
    prompt = f"""
    Based on the following text, generate question-answer pairs. Focus on identifying
    potential problems and the corresponding solutions mentioned in the text. Format
    the output with clear questions and answers.

    Text:
    {text}
    """
    response = model.generate_content(prompt)
    return response.text

def generate_step_by_step_qa(text):
    """
    Generates question-answer pairs focusing on extracting procedural steps from the text.

    This method is designed to identify and present sequential steps outlined in the input text.
    It prompts the AI model to understand the order of operations and frame questions around
    these steps. This is particularly useful for extracting instructions or troubleshooting
    procedures from technical documentation.

    Args:
        text: The input string containing the content with sequential steps.

    Returns:
        str: The generated question-answer pairs focusing on steps, formatted as a string.
    """
    model = genai.GenerativeModel('gemini-1.5-flash')
    prompt = f"""
    From the following text, extract the step-by-step instructions for fixing a
    heating issue in a Samsung microwave. Generate question-answer pairs where
    the question asks what the next step is at a particular point, or what a specific
    step involves.

    Text:
    {text}
    """
    response = model.generate_content(prompt)
    return response.text

# Example Usage:
print("--- Simple Question-Answer Pairs ---")
simple_qa = generate_qa_pairs(content)
print(simple_qa)

print("\n--- Structured Question-Answer Pairs ---")
structured_qa = generate_structured_qa(content)
print(structured_qa)

print("\n--- Step-by-Step Question-Answer Pairs ---")
step_qa = generate_step_by_step_qa(content)
print(step_qa)
# Out:
# --- Simple Question-Answer Pairs ---
# ## Samsung Microwave Support: Question-Answer Pairs
#
# **General:**
#
# **Q:** What resources does Samsung provide to support its microwave users?
# **A:** Samsung offers user manuals, online support pages (including FAQs, troubleshooting guides, how-to videos, and software updates), and community forums.
#
# **Q:** Why is it important to consult support documentation before contacting customer support?
# **A:** Consulting documentation can often resolve common issues quickly and efficiently, saving time and effort.
#
# **Q:** What crucial information is needed when using Samsung's online support resources?
# **A:** The model number of your microwave is crucial for accessing specific information.
#
# **Microwave Not Heating:**
#
# **Q:** My Samsung microwave isn't heating. What are the initial troubleshooting steps?
# **A:** Check the power supply (outlet, circuit breaker, power cord), ensure the door is properly closed and sealed, and inspect for any obstructions.
#
# **Q:** If the power supply and door are fine, what could be causing my microwave to not heat?
# **A:**  A faulty magnetron, high-voltage diode, capacitor, or control panel issues could be the cause. These often require professional repair.
#
# **Microwave Not Turning On:**
#
# **Q:** My Samsung microwave won't turn on. What should I check?
# **A:** Check the power supply (outlet, circuit breaker, power cord) and see if the control panel lock is enabled.  An internal fuse may also be blown, requiring professional repair.
#
# **Arcing or Sparks:**
#
# **Q:** I'm seeing arcing or sparks inside my microwave. What's the likely cause?
# **A:**  This is often caused by metal objects inside the microwave, a damaged waveguide cover, or food debris.
#
# **Q:** How do I prevent arcing or sparks in my Samsung microwave?
# **A:** Avoid placing metal objects inside, replace a damaged waveguide cover, and clean the interior thoroughly.
#
#
# **Turntable Not Rotating:**
#
# **Q:** The turntable in my Samsung microwave isn't spinning. What's wrong?
# **A:** Check if the turntable is correctly placed on the track and that there are no obstructions.  A faulty turntable motor may also be the issue.
#
#
# **Error Codes:**
#
# **Q:** My Samsung microwave is displaying an error code. How can I troubleshoot this?
# **A:** Consult your user manual or Samsung's online support pages for a database of error codes and their meanings.
#
# **Contacting Samsung Support:**
#
# **Q:** What information should I have ready when contacting Samsung support about my microwave?
# **A:**  Have your microwave's model number, serial number, and a clear description of the problem ready.
#
#
# **General Troubleshooting:**
#
# **Q:** Where can I find a downloadable user manual for my Samsung microwave?
# **A:** You can download a digital copy from Samsung's website using your microwave's model number.
#
# **Q:** When should I call a qualified technician for my Samsung microwave repair?
# **A:** Call a qualified technician for issues involving high-voltage components (magnetron, diode, capacitor), internal mechanisms, or if simpler troubleshooting steps fail.
#
#
# --- Structured Question-Answer Pairs ---
# Here are some question-answer pairs based on the provided text, focusing on problems and their solutions:
#
#
# **Problem: Microwave Not Heating**
#
# * **Q:** My Samsung microwave isn't heating my food. What are some possible causes?
# * **A:**  Several things could be wrong:  a faulty power supply (check the outlet, circuit breaker, and power cord), a problem with the door interlock system (ensure the door is fully closed and the seals are clean), a malfunctioning magnetron (requiring professional repair), a faulty high-voltage diode or capacitor (requiring professional repair), or control panel issues (possibly a software or hardware problem).
#
# **Problem: Microwave Not Turning On**
#
# * **Q:** My Samsung microwave won't turn on at all. What should I check?
# * **A:** First, check the power supply (outlet, circuit breaker, and power cord).  Next, see if the control panel lock is enabled (consult your user manual). Finally, there might be a blown internal fuse (requiring professional repair).
#
# **Problem: Arcing or Sparks Inside the Microwave**
#
# * **Q:** I'm seeing sparks inside my Samsung microwave. What's causing this?
# * **A:** This is dangerous!  It's likely due to metal objects inside (never put metal in a microwave), a damaged waveguide cover (replace it), or food debris (clean the interior thoroughly).
#
# **Problem: Turntable Not Rotating**
#
# * **Q:** The turntable in my Samsung microwave isn't spinning. What's wrong?
# * **A:** Make sure the turntable is correctly placed on its track and that nothing is obstructing its rotation. If that's not the issue, the turntable motor might be faulty.
#
#
# **Problem: Error Codes Displayed**
#
# * **Q:** My Samsung microwave is displaying an error code. How can I find out what it means?
# * **A:** Consult your user manual for a description of the error code and troubleshooting steps.  You can also check Samsung's online support pages for a database of error codes.
#
# **Problem:  Difficulty Troubleshooting**
#
# * **Q:** I've tried basic troubleshooting but my Samsung microwave still isn't working. What should I do?
# * **A:** Utilize Samsung's online resources (FAQs, troubleshooting guides, how-to videos) using your microwave's model number. If those don't help, contact Samsung support, providing your model and serial numbers, and a clear description of the problem.  Remember to only attempt repairs involving high voltage components yourself if you're a qualified technician.
#
#
# --- Step-by-Step Question-Answer Pairs ---
# Here's a step-by-step guide to troubleshooting a Samsung microwave heating issue, presented as question-answer pairs:
#
# **Troubleshooting a Samsung Microwave Not Heating:**
#
# 1. **Q: What's the first step to troubleshoot a microwave that isn't heating?**
#    **A:** Check the power supply: Make sure the microwave is plugged into a working outlet, and check the circuit breaker or fuse box to ensure power is getting to the outlet.  Also, inspect the power cord for any damage.
#
# 2. **Q: What should I do if the power supply seems fine?**
#    **A:** Examine the door interlock system.  Ensure the door is completely closed and latched, and that there are no obstructions preventing it from closing properly.  Also, check the door seals for cleanliness and damage.
#
# 3. **Q: If the door and power are okay, what component might be the problem?**
#    **A:** The magnetron might be faulty. This requires professional repair.
#
# 4. **Q:  Are there other components that could prevent heating besides the magnetron?**
#    **A:** Yes, a faulty high-voltage diode or capacitor in the high-voltage circuit could also be the cause.  These should only be checked and repaired by a qualified technician due to the high voltages involved.
#
# 5. **Q: What if the problem isn't with the power or the internal components?**
#    **A:** A malfunctioning control panel might be preventing the microwave from heating. This may be a software or hardware issue, and professional repair may be necessary.
#
#
# **Important Note:**  The questions and answers focus solely on the "Microwave Not Heating" section, as requested. Other issues (like the microwave not turning on, arcing, etc.) are addressed in the original text but not included in this Q&A format.  Always prioritize safety and consult a qualified technician for repairs involving high-voltage components.

# %%
import google.generativeai as genai
from textwrap import dedent

# Configure the API key (make sure to set this up in your environment)
# genai.configure(api_key=userdata.get('GOOGLE_API_KEY'))
content = generated_text
def generate_basic_qa(text):
    """
    Generates fundamental question-answer pairs covering key aspects of the text.
    """
    model = genai.GenerativeModel('gemini-1.5-flash')
    prompt = dedent(f"""
    Analyze the following Samsung support document and generate comprehensive question-answer pairs.
    Focus on:
    - Device-specific features and functionalities
    - Proper usage instructions
    - Technical specifications
    - Basic troubleshooting
    - Maintenance guidelines

    Format requirements:
    - Start with a numbered list
    - Use clear, consumer-friendly language
    - Keep answers concise (1-2 sentences)
    - Phrase questions as natural customer inquiries

    Document content:
    {text}
    """)
    response = model.generate_content(prompt)
    return response.text

def generate_troubleshooting_qa(text):
    """
    Generates QA pairs focused on common issues and solutions.
    """
    model = genai.GenerativeModel('gemini-1.5-flash')
    prompt = dedent(f"""
    Create detailed troubleshooting Q&A pairs from this Samsung support text.
    For each entry include:
    1. Problem description (as question)
    2. Step-by-step solution
    3. Required tools/materials
    4. Safety precautions
    5. Error code explanations (if applicable)

    Structure each pair as:
    Q [number]: [Problem description with device context]
    A: - [Step 1]
       - [Step 2]
       - [Additional notes]

    Input text:
    {text}
    """)
    response = model.generate_content(prompt)
    return response.text

def generate_error_code_qa(text):
    """
    Generates QA pairs specifically for error code explanations.
    """
    model = genai.GenerativeModel('gemini-1.5-flash')
    prompt = dedent(f"""
    Extract and explain error codes from the Samsung technical document.
    For each error code create:
    - Standard question format: "What does error code [CODE] mean on [DEVICE]?"
    - Detailed answer including:
      * Meaning of the error
      * Common causes
      * Recommended solutions
      * When to contact support

    Document content:
    {text}
    """)
    response = model.generate_content(prompt)
    return response.text

def generate_preventive_maintenance_qa(text):
    """
    Generates QA pairs about maintenance and prevention.
    """
    model = genai.GenerativeModel('gemini-1.5-flash')
    prompt = dedent(f"""
    Create maintenance-focused Q&A pairs from this Samsung guide.
    Include:
    - Recommended cleaning procedures
    - Component replacement schedules
    - Performance optimization tips
    - Storage recommendations
    - Signs of wear to watch for

    Format each answer as:
    - [Action]: [Frequency]
    - [Task]: [Detailed instructions]
    - [Warning signs]: [Descriptions]

    Text content:
    {text}
    """)
    response = model.generate_content(prompt)
    return response.text

def generate_safety_qa(text):
    """
    Generates QA pairs focused on safety information.
    """
    model = genai.GenerativeModel('gemini-1.5-flash')
    prompt = dedent(f"""
    Extract safety-related information and create critical Q&A pairs.
    For each safety point include:
    - Risk description (as question)
    - Potential consequences
    - Prevention methods
    - Emergency procedures

    Format with clear warnings and highlight dangerous scenarios.
    Use caution symbols (🛑) for critical warnings.

    Document text:
    {text}
    """)
    response = model.generate_content(prompt)
    return response.text

def generate_compatibility_qa(text):
    """
    Generates QA pairs about device compatibility.
    """
    model = genai.GenerativeModel('gemini-1.5-flash')
    prompt = dedent(f"""
    Create compatibility-focused Q&A pairs from this Samsung document.
    Include:
    - Supported accessories/models
    - Software/hardware requirements
    - Regional variations
    - Generation-specific features
    - Upgrade paths

    Structure answers with:
    - Compatible items list
    - Version requirements
    - Limitations/caveats
    - Purchase recommendations

    Content:
    {text}
    """)
    response = model.generate_content(prompt)
    return response.text

# Example Usage in Jupyter Notebook
print("## Basic Device Q&A ##")
print(generate_basic_qa(content))

print("\n## Troubleshooting Guide ##")
print(generate_troubleshooting_qa(content))

print("\n## Error Code Reference ##")
print(generate_error_code_qa(content))

print("\n## Maintenance Schedule ##")
print(generate_preventive_maintenance_qa(content))

print("\n## Safety Information ##")
print(generate_safety_qa(content))

print("\n## Compatibility Check ##")
print(generate_compatibility_qa(content))
# Out:
# ## Basic Device Q&A ##
# 1. **Q: My Samsung microwave isn't heating my food. What should I check first?**
#
#    **A:**  First, ensure the microwave is plugged in securely to a working outlet and check your circuit breaker or fuse box.  Then, confirm the door is completely closed and the seals are clean and intact.
#
# 2. **Q: My Samsung microwave won't turn on at all. What could be wrong?**
#
#    **A:** Check that the power cord is properly connected and the outlet is working. Also, see if the control panel lock is activated (check your manual for instructions to disable it).
#
# 3. **Q: I'm seeing sparks inside my Samsung microwave. What should I do?**
#
#    **A:** Immediately unplug the microwave. Never put metal objects inside. Check for food debris or a damaged waveguide cover; clean thoroughly or replace the cover as needed.
#
# 4. **Q: The turntable in my Samsung microwave isn't spinning. How do I fix it?**
#
#    **A:** Make sure the turntable is correctly positioned on its track and that nothing is obstructing its rotation.  If the problem persists, the motor might be faulty and require professional repair.
#
# 5. **Q: My Samsung microwave is displaying an error code. Where can I find out what it means?**
#
#    **A:** Consult your user manual for a list of error codes and their explanations. You can also search for your model number on Samsung's online support pages.
#
# 6. **Q: Where can I find the user manual for my Samsung microwave if I lost the physical copy?**
#
#    **A:** You can download a digital copy of your user manual from Samsung's website; you'll need your microwave's model number.
#
# 7. **Q:  What safety precautions should I take when using my Samsung microwave?**
#
#    **A:** Never operate the microwave with the door open, avoid putting metal objects inside, and always let food cool down after heating before removing it.  Clean spills promptly.
#
# 8. **Q: How often should I clean my Samsung microwave?**
#
#    **A:** Clean your microwave regularly, especially after spills, to prevent food build-up that can affect performance and cause sparking.  Refer to your manual for specific cleaning instructions.
#
# 9. **Q: What information do I need to provide if I contact Samsung support about a problem with my microwave?**
#
#    **A:** You'll need your microwave's model number and serial number, along with a clear description of the problem you are experiencing.
#
# 10. **Q:  What should I do if I suspect a problem with the high-voltage components in my Samsung microwave (like the magnetron)?**
#
#     **A:** Do not attempt to repair these components yourself. Contact a qualified technician for professional repair to avoid potential electrical hazards.
#
# 11. **Q: Where can I find troubleshooting videos for my Samsung microwave?**
#
#     **A:** Samsung's online support pages for your specific model number may offer how-to videos for troubleshooting common problems.
#
# 12. **Q: Does Samsung offer online forums for troubleshooting microwave problems?**
#
#     **A:** Yes, Samsung may have community forums where you can connect with other users and potentially find solutions to your problems.  Samsung representatives may also participate.
#
#
# ## Troubleshooting Guide ##
# Q1: My Samsung microwave isn't heating my food.
#
# A: - **Step 1:** Check if the microwave is plugged into a working power outlet.  Check the circuit breaker or fuse box to ensure power isn't interrupted. Inspect the power cord for any visible damage (cracks, fraying).
#    - **Step 2:** Ensure the microwave door is completely closed and latched. Examine the door seals for any debris or damage that might prevent a proper seal.
#    - **Step 3:** If the problem persists, the magnetron, high-voltage diode, or capacitor might be faulty.  These components require professional repair due to high voltage risks. Contact Samsung support or a qualified appliance repair technician.
#    - **Additional notes:**  A malfunctioning control panel could also be the cause.
#
#
# Required tools/materials: None for initial troubleshooting.  Professional tools are needed for magnetron, diode, or capacitor repair.
#
# Safety precautions:  Never attempt to repair high-voltage components yourself. Always unplug the microwave from the power outlet before attempting any inspection or cleaning.
#
# Error code explanations: Not directly addressed in the provided text.  Refer to your user manual for specific error codes and their meaning.
#
#
# Q2: My Samsung microwave won't turn on at all.
#
# A: - **Step 1:** Verify the microwave is plugged into a functioning power outlet. Check the circuit breaker and fuse box. Inspect the power cord for damage.
#    - **Step 2:** Consult your user manual to see if a control panel lock is enabled and how to disable it.
#    - **Step 3:** If the microwave remains unresponsive, an internal fuse may have blown.  This requires professional repair. Contact Samsung support or a qualified appliance repair technician.
#    - **Additional notes:** Ensure the power outlet itself is working by testing it with another appliance.
#
# Required tools/materials: None for initial troubleshooting. Professional tools are needed for fuse replacement.
#
# Safety precautions:  Always unplug the microwave from the power outlet before attempting any inspection.  Never attempt internal repairs unless qualified.
#
# Error code explanations:  Not directly addressed in the provided text. Refer to your user manual for specific error codes and their meaning.
#
#
# Q3: I'm seeing arcing or sparks inside my Samsung microwave.
#
# A: - **Step 1:** Remove any metal objects from inside the microwave. Metal objects can cause arcing and are a fire hazard.
#    - **Step 2:** Inspect the waveguide cover for damage.  A damaged waveguide cover can cause arcing. Replace the damaged cover if necessary.
#    - **Step 3:** Thoroughly clean the interior of the microwave to remove any food debris that may be causing arcing.
#    - **Additional notes:** If arcing persists after these steps, contact Samsung support or a qualified technician.
#
# Required tools/materials:  Cleaning supplies, replacement waveguide cover (if needed).
#
# Safety precautions: Unplug the microwave before cleaning or inspecting.  Never touch internal components while the microwave is plugged in. Avoid operating the microwave if arcing occurs.
#
# Error code explanations:  Not directly addressed in the provided text. Refer to your user manual for specific error codes and their meaning.
#
#
# Q4: The turntable in my Samsung microwave isn't rotating.
#
# A: - **Step 1:** Check that the turntable is correctly positioned on its track.
#    - **Step 2:** Inspect the turntable track for any obstructions preventing rotation (food debris, etc.). Remove any obstructions.
#    - **Step 3:** If the turntable still doesn't rotate, the turntable motor might be faulty. This will require professional repair.
#    - **Additional notes:** Ensure nothing is blocking the turntable's movement.
#
# Required tools/materials: None for initial troubleshooting.
#
# Safety precautions: Unplug the microwave before attempting any inspection or cleaning.
#
# Error code explanations:  Not directly addressed in the provided text. Refer to your user manual for specific error codes and their meaning.
#
#
# Q5: My Samsung microwave is displaying an error code.
#
# A: - **Step 1:** Locate your microwave's user manual.  The manual will contain a list of error codes and their corresponding solutions.
#    - **Step 2:** If you don't have the manual, visit Samsung's online support website and search for your microwave model number.  Their online resources often include error code databases.
#    - **Step 3:** If you can't find the solution online or in your manual, contact Samsung support.
#    - **Additional notes:**  Always note the exact error code displayed for faster troubleshooting.
#
# Required tools/materials: User manual or access to the internet.
#
# Safety precautions: Follow all safety instructions provided in the user manual or online support documentation related to the specific error code.
#
# Error code explanations: The specific error code meaning will be provided in the user manual or on Samsung's website.
#
#
# ## Error Code Reference ##
# The provided document doesn't list specific error codes.  It only mentions that error codes should be looked up in the user manual or on Samsung's online support pages.  Therefore, I cannot create Q&A entries for specific error codes.  However, I can provide a template for creating such entries once the error codes are identified from a user manual or the Samsung support website.
#
#
# **Template for Error Code Q&A:**
#
# **Standard Question Format:** "What does error code [CODE] mean on a Samsung Microwave?"
#
# **Detailed Answer:**
#
# * **Meaning of the error:** [Insert the meaning of the error code from the Samsung documentation.  Explain what the malfunction is indicating.]
#
# * **Common causes:** [List the most frequent reasons why this error code appears.  This might include hardware failures, sensor problems, software glitches, or user errors.]
#
# * **Recommended solutions:**  [Provide a step-by-step guide on how to try and fix the problem.  This may include checking connections, resetting the microwave, cleaning components, or replacing parts.  Clearly distinguish between solutions a user can try and those requiring professional help.]
#
# * **When to contact support:** [Specify when it's advisable to contact Samsung support. This might be after trying the troubleshooting steps unsuccessfully, if the problem is recurring, or if the error code indicates a serious safety hazard.  Always emphasize that attempting repairs involving high voltage components should only be done by qualified technicians.]
#
#
# **Example using the information given, focusing on the general lack of heating:**
#
# **Standard Question Format:** "What does a lack of heating mean on a Samsung Microwave?"  (This is not an error code, but a common problem)
#
#
# **Detailed Answer:**
#
# * **Meaning of the error:** The microwave is not generating enough heat to cook or reheat food. This means the food remains cold or only slightly warm after the set cooking time.
#
# * **Common causes:** This could be due to a power supply issue (incorrectly plugged in, blown fuse, tripped circuit breaker), a problem with the door interlock system (door not properly closed), a malfunctioning magnetron (the component that generates microwaves), a faulty high-voltage diode or capacitor, or a problem with the control panel.
#
# * **Recommended solutions:**
#     1. **Check the power supply:** Ensure the microwave is plugged into a working outlet and that the circuit breaker or fuse hasn't tripped.  Inspect the power cord for damage.
#     2. **Check the door:** Make sure the door is completely closed and that there are no obstructions preventing it from latching. Clean the door seals.
#     3. **Inspect the control panel:** Look for any obvious damage or unusual behavior on the control panel.
#     4. **If the above steps fail:**  Do NOT attempt to repair the magnetron, high-voltage diode, or capacitor yourself. These components work with high voltage and pose a risk of electric shock. Contact Samsung support or a qualified appliance repair technician.
#
# * **When to contact support:** Contact support if the microwave still doesn't heat after checking the power supply and door interlock.  Contact support immediately if you suspect a problem with the high-voltage components (strong smell, sparking, etc.).  Never attempt to repair these yourself.
#
#
# ## Maintenance Schedule ##
# ## Samsung Microwave Maintenance Q&A
#
# **Cleaning Procedures:**
#
# - **[Action]:** Clean interior surfaces
# - **[Frequency]:** After each use
# - **[Task]:** Wipe down the interior with a damp, non-abrasive cloth or sponge.  For stubborn spills, allow them to soak before wiping. Avoid harsh chemicals.
# - **[Warning signs]:**  Buildup of food residue, visible stains, sticky surfaces.
#
#
# **Component Replacement:**
#
# - **[Action]:**  Replace waveguide cover
# - **[Frequency]:** As needed, if damaged
# - **[Task]:** Carefully remove the damaged waveguide cover and replace it with a new one.  Consult your user manual for specific instructions.  This may require professional assistance.
# - **[Warning signs]:** Cracks or holes in the waveguide cover; arcing or sparking inside the microwave.
#
# - **[Action]:** Replace turntable
# - **[Frequency]:** As needed, if cracked or damaged
# - **[Task]:**  Purchase a replacement turntable (ensure compatibility with your model). Carefully install the new turntable.
# - **[Warning signs]:** Cracked or broken turntable; turntable not rotating smoothly.
#
# - **[Action]:** Magnetron replacement
# - **[Frequency]:** As needed, by a qualified technician
# - **[Task]:** This is a high-voltage component and should ONLY be replaced by a qualified technician.
# - **[Warning signs]:** Microwave not heating, despite other checks.
#
#
# **Performance Optimization:**
#
# - **[Action]:** Check door seal
# - **[Frequency]:** Periodically (e.g., every 6 months)
# - **[Task]:** Inspect the door seal for any damage, cracks, or debris. Clean thoroughly if needed.
# - **[Warning signs]:** Microwave not heating effectively; steam escaping from the door.
#
# - **[Action]:** Inspect turntable motor
# - **[Frequency]:** If turntable malfunctions
# - **[Task]:**  This should be checked by a qualified technician.  Ensure the turntable is properly seated and free of obstructions before calling for service.
# - **[Warning signs]:** Turntable does not rotate.
#
#
# **Storage Recommendations:**
#
# - **[Action]:** Store properly when not in use
# - **[Frequency]:** Always
# - **[Task]:** Keep the microwave clean and dry when not in use. Do not store anything on top of the microwave that might block ventilation.
# - **[Warning signs]:** None specifically, but proper storage prevents damage and overheating.
#
#
# **Signs of Wear to Watch For:**
#
# - **[Action]:** Monitor for arcing/sparks
# - **[Frequency]:** During use
# - **[Task]:** If you see arcing or sparks, immediately stop using the microwave and unplug it. Check for metal objects or food debris.
# - **[Warning signs]:** Sparks or arcing inside the microwave; burning smell.
#
# - **[Action]:**  Check for error codes
# - **[Frequency]:**  If microwave malfunctions
# - **[Task]:** Consult the user manual or Samsung's online support for explanations of error codes.
# - **[Warning signs]:** Error codes displayed on the control panel.
#
# - **[Action]:** Inspect power cord
# - **[Frequency]:** Periodically
# - **[Task]:** Check the power cord for any fraying, damage, or cracks.
# - **[Warning signs]:** Damaged or frayed power cord.
#
#
# ## Safety Information ##
# ## Samsung Microwave Safety: Critical Q&A
#
# **🛑 WARNING:  Improper use of a microwave can lead to serious injury or property damage. Always follow the manufacturer's instructions and safety precautions.**
#
#
# **1. Microwave Not Heating:**
#
# * **Risk Description (Question):**  My Samsung microwave isn't heating food. What could be causing this, and is it safe to continue trying to use it?
# * **Potential Consequences:**  Food remains uncooked or improperly heated, leading to foodborne illness.  A faulty magnetron or high-voltage components could pose a shock or fire hazard if improperly handled. Prolonged attempts to troubleshoot may cause further damage.
# * **Prevention Methods:** Regularly check the power cord for damage. Ensure the door is properly closed and the seals are clean.  Do not attempt repairs involving high-voltage components (magnetron, diode, capacitor) yourself.
# * **Emergency Procedures:** If you suspect a problem with the high-voltage components, immediately unplug the microwave and contact a qualified technician. Do not attempt to open the microwave casing.
#
#
# **2. Microwave Not Turning On:**
#
# * **Risk Description (Question):** My Samsung microwave won't turn on. Is this a simple fix, or could it indicate a serious problem?
# * **Potential Consequences:** Inconvenience and inability to cook or reheat food. A blown internal fuse could indicate a more serious underlying problem that may be a fire hazard if not addressed.
# * **Prevention Methods:** Regularly check the power cord for damage.  Familiarize yourself with the control panel lock feature to avoid accidental activation/deactivation.
# * **Emergency Procedures:** If the microwave is completely unresponsive and you suspect a blown fuse, unplug it immediately and contact a qualified technician. Do not attempt to access internal components.
#
#
# **3. Arcing or Sparks Inside the Microwave:**
#
# * **Risk Description (Question):**  I'm seeing arcing or sparks inside my Samsung microwave. What should I do?  **🛑 DANGER: This is a serious safety hazard.**
# * **Potential Consequences:**  **Fire hazard.**  Severe burns from contact with hot, sparking components.  Damage to the microwave and possible injury.
# * **Prevention Methods:** Never place metal objects (utensils, foil) inside the microwave.  Regularly clean the interior of the microwave to remove food debris.  Inspect and replace a damaged waveguide cover immediately.
# * **Emergency Procedures:**  **Immediately unplug the microwave.** Do not attempt to operate it further. Contact a qualified technician for repair or replacement.  Do not touch any internal components.
#
#
# **4.  Metal Objects in the Microwave:**
#
# * **Risk Description (Question):** Is it safe to put metal objects in my Samsung microwave?  **🛑 DANGER: This can be extremely dangerous.**
# * **Potential Consequences:**  **Serious risk of fire and burns.** Metal objects can cause arcing and sparks, potentially igniting food or causing a fire.  The microwave itself could be damaged beyond repair.
# * **Prevention Methods:**  Never place metal objects (utensils, foil, etc.) inside the microwave. Use only microwave-safe containers.
# * **Emergency Procedures:** If a fire starts, immediately unplug the microwave and evacuate the area. Call the fire department.
#
#
# **5.  Damaged Microwave:**
#
# * **Risk Description (Question):**  My Samsung microwave has a visible crack or damage. Is it still safe to use?  **🛑 DANGER:  A damaged microwave can pose serious risks.**
# * **Potential Consequences:**  Exposure to high voltage components. Risk of electric shock or fire.
# * **Prevention Methods:** Do not use a damaged microwave.
# * **Emergency Procedures:**  Unplug the microwave immediately. Contact a qualified technician for repair or replacement.
#
#
# **General Safety Precautions:**
#
# * Always consult the user manual for specific safety instructions related to your microwave model.
# * Never operate the microwave if it is damaged or malfunctioning.
# * Keep children away from the microwave when it is in operation.
# * Do not attempt to repair the microwave yourself unless you are a qualified technician.
# * Always unplug the microwave before cleaning or performing any maintenance.
#
#
# **Remember:**  If you are unsure about anything, err on the side of caution. Contact a qualified technician for any repairs or concerns about the safety of your Samsung microwave.
#
#
# ## Compatibility Check ##
# The provided text focuses on troubleshooting and doesn't offer specifics on accessory compatibility, software/hardware requirements, regional variations, generation-specific features, or upgrade paths.  Therefore, a compatibility-focused Q&A is impossible to create from this document alone.  The document solely addresses how to troubleshoot common Samsung microwave problems.  To create the desired Q&A, information on Samsung microwave model specifications and variations would be needed.

# %%
import google.generativeai as genai

# apikey=userdata.get('GOOGLE_API_KEY')  # You'll need to set your API key
# gen
content = generated_text
# content = """
# If your Samsung microwave is not heating, here are some troubleshooting steps you can take:

# 1. **Check the Power Cord and Outlet:** Ensure the microwave is properly plugged into a working power outlet. Test the outlet with another device to confirm it's supplying power.

# 2. **Inspect the Door Latch:** The microwave has safety interlocks that prevent it from operating if the door is not closed correctly. Make sure the door closes firmly and the latch engages properly.  Sometimes food debris or damage can prevent proper latching.

# 3. **Test with a Different Power Level:** Try heating something at a higher power level. If it heats at higher power but not at lower levels, there might be an issue with the magnetron or power control circuitry, requiring professional service.

# 4. **Listen for the Magnetron:** When you start the microwave, you should hear a humming sound, which indicates the magnetron is working. If you don't hear this sound, the magnetron might be faulty.  (Note: Do not operate the microwave empty for extended periods to test this.)

# 5. **Check the User Manual:** Refer to your Samsung microwave's user manual for specific troubleshooting steps and error codes.  The manual may contain model-specific guidance.

# 6. **Contact Samsung Support:** If none of the above steps resolve the issue, or if you suspect a more serious problem like a faulty magnetron, contact Samsung customer support or a qualified appliance repair technician for assistance.  Do not attempt to repair internal components yourself as this can be dangerous and void your warranty.
# """

def generate_qa_pairs(text):
    """
    Generates general informative question-answer pairs from Samsung support documentation.

    Focuses on extracting key information and presenting it in a simple Q&A format
    suitable for quick understanding of Samsung product features or issues.

    Args:
        text: The input string containing Samsung support document content.

    Returns:
        str: The generated question-answer pairs formatted as a string.
    """
    model = genai.GenerativeModel('gemini-1.5-flash')
    prompt = f"""
    Generate informative question-answer pairs based on the following Samsung support document text.
    Focus on extracting key facts and information that a user might find helpful.

    Text:
    {text}
    """
    response = model.generate_content(prompt)
    return response.text

def generate_structured_qa(text):
    """
    Generates problem-solution focused question-answer pairs from Samsung support documentation.

    Identifies potential problems related to Samsung products/services mentioned in the text
    and extracts the corresponding solutions or recommendations. This is helpful for
    troubleshooting guides and support articles.

    Args:
        text: The input string containing Samsung support document content.

    Returns:
        str: The generated problem-solution question-answer pairs, formatted as a string.
    """
    model = genai.GenerativeModel('gemini-1.5-flash')
    prompt = f"""
    Based on the following Samsung support document text, generate question-answer pairs.
    Focus on identifying potential problems a user might encounter with a Samsung product
    and the corresponding solutions or troubleshooting steps mentioned in the text.
    Format the output with clear questions (starting with "Problem:") and answers (starting with "Solution:").

    Text:
    {text}
    """
    response = model.generate_content(prompt)
    return response.text

def generate_step_by_step_qa(text):
    """
    Generates step-by-step instruction question-answer pairs from Samsung support documentation.

    Extracts procedural steps for tasks like troubleshooting, setup, or feature usage of
    Samsung devices. Questions are designed to guide users through the steps sequentially.

    Args:
        text: The input string containing Samsung support document content with steps.

    Returns:
        str: The generated step-by-step question-answer pairs, formatted as a string.
    """
    model = genai.GenerativeModel('gemini-1.5-flash')
    prompt = f"""
    From the following Samsung support document text, extract step-by-step instructions.
    Generate question-answer pairs where the question prompts for the next step in a procedure
    or asks for details about a specific step. Focus on actions a user needs to perform.
    Use questions like "What is the next step after...?" or "How do I perform step ...?".

    Text:
    {text}
    """
    response = model.generate_content(prompt)
    return response.text

def generate_faq_qa(text):
    """
    Generates FAQ (Frequently Asked Questions) style question-answer pairs from Samsung support documentation.

    Aims to identify common questions users might have about a Samsung product, feature, or service
    based on the provided support text. Questions are phrased as if a user is asking for help.

    Args:
        text: The input string containing Samsung support document content.

    Returns:
        str: The generated FAQ-style question-answer pairs, formatted as a string.
    """
    model = genai.GenerativeModel('gemini-1.5-flash')
    prompt = f"""
    Based on the following Samsung support document text, generate Frequently Asked Questions (FAQ)
    style question-answer pairs.  Think about what questions a typical Samsung user might ask
    after reading this documentation. Phrase the questions naturally, as a user would ask.

    Text:
    {text}
    """
    response = model.generate_content(prompt)
    return response.text

def generate_troubleshooting_qa(text):
    """
    Generates troubleshooting-focused question-answer pairs from Samsung support documentation.

    Specifically targets questions and answers related to diagnosing and resolving issues
    with Samsung products. Questions often start with "How do I fix..." or "What to do if...".

    Args:
        text: The input string containing Samsung support document content.

    Returns:
        str: The generated troubleshooting question-answer pairs, formatted as a string.
    """
    model = genai.GenerativeModel('gemini-1.5-flash')
    prompt = f"""
    From the following Samsung support document text, generate troubleshooting-focused
    question-answer pairs. Focus on questions related to diagnosing and fixing problems
    with Samsung products.  Use question formats like "How do I fix...?", "What should I do if...?",
    or "Why is my Samsung device... not working?".

    Text:
    {text}
    """
    response = model.generate_content(prompt)
    return response.text

def generate_feature_explanation_qa(text):
    """
    Generates question-answer pairs explaining features of Samsung products from support documentation.

    Focuses on extracting descriptions of features and functionalities of Samsung devices or services.
    Questions are about understanding what a feature does or how it works.

    Args:
        text: The input string containing Samsung support document content.

    Returns:
        str: The generated feature explanation question-answer pairs, formatted as a string.
    """
    model = genai.GenerativeModel('gemini-1.5-flash')
    prompt = f"""
    Based on the following Samsung support document text, generate question-answer pairs
    that explain the features or functionalities of Samsung products.  Focus on understanding
    what specific features do and how they work.  Questions should be about feature descriptions
    and their purpose.  Start questions with phrases like "What is...?", "What does... mean?",
    or "How does... work?".

    Text:
    {text}
    """
    response = model.generate_content(prompt)
    return response.text

def generate_setup_qa(text):
    """
    Generates setup and configuration related question-answer pairs from Samsung support documentation.

    Targets information about setting up or configuring Samsung devices or services.
    Questions are about the initial setup process or how to configure specific settings.

    Args:
        text: The input string containing Samsung support document content.

    Returns:
        str: The generated setup/configuration question-answer pairs, formatted as a string.
    """
    model = genai.GenerativeModel('gemini-1.5-flash')
    prompt = f"""
    From the following Samsung support document text, generate question-answer pairs related to
    setting up or configuring Samsung devices or services. Focus on the initial setup process and
    configuration options. Questions should be about how to set up or configure aspects of a
    Samsung product. Use questions like "How do I set up...?", "How do I configure...?",
    or "What are the setup steps for...?".

    Text:
    {text}
    """
    response = model.generate_content(prompt)
    return response.text


# Example Usage:
print("--- Simple Question-Answer Pairs ---")
simple_qa = generate_qa_pairs(content)
print(simple_qa)

print("\n--- Structured Question-Answer Pairs (Problem-Solution) ---")
structured_qa = generate_structured_qa(content)
print(structured_qa)

print("\n--- Step-by-Step Question-Answer Pairs ---")
step_qa = generate_step_by_step_qa(content)
print(step_qa)

print("\n--- FAQ Style Question-Answer Pairs ---")
faq_qa = generate_faq_qa(content)
print(faq_qa)

print("\n--- Troubleshooting Question-Answer Pairs ---")
troubleshooting_qa = generate_troubleshooting_qa(content)
print(troubleshooting_qa)

print("\n--- Feature Explanation Question-Answer Pairs ---")
feature_qa = generate_feature_explanation_qa(content)
print(feature_qa)

print("\n--- Setup & Configuration Question-Answer Pairs ---")
setup_qa = generate_setup_qa(content)
print(setup_qa)
# Out:
# --- Simple Question-Answer Pairs ---
# ## Samsung Microwave Troubleshooting: Q&A
#
# **General Information:**
#
# **Q: Where can I find Samsung microwave support documentation?**
# A: Samsung provides support through user manuals (included with the microwave), online support pages (accessible via their website using your microwave's model number), and community forums.
#
# **Q: What information is crucial when seeking online support for my Samsung microwave?**
# A:  Your microwave's model number is essential for accessing specific troubleshooting guides, manuals, and FAQs.  The serial number may also be helpful for support representatives.
#
# **Troubleshooting Specific Issues:**
#
# **Q: My Samsung microwave isn't heating. What should I check?**
# A: First, ensure it's properly plugged in and the power outlet is working.  Check the circuit breaker/fuse box. Next, verify the door is completely closed and the seals are clean and intact. If the problem persists, the magnetron (requiring professional repair) or other high-voltage components may be faulty. A malfunctioning control panel is also possible.
#
# **Q: My Samsung microwave won't turn on. What are the potential causes?**
# A: Check the power supply (outlet, circuit breaker, power cord).  See if the control panel lock is accidentally activated (consult your user manual).  An internal fuse might have blown (requiring professional repair).
#
#
# **Q: I'm seeing sparks or arcing inside my Samsung microwave. What's wrong?**
# A:  This is dangerous!  Avoid using the microwave immediately. This usually indicates metal objects inside (never put metal in a microwave!), a damaged waveguide cover (replace it), or food debris (clean thoroughly).
#
# **Q: The turntable in my Samsung microwave isn't rotating. How do I fix it?**
# A: Make sure the turntable is correctly positioned on its track and that nothing is obstructing its rotation. If the problem continues, the turntable motor might be broken and require professional repair.
#
# **Q: My Samsung microwave is displaying an error code. What should I do?**
# A: Consult your user manual for a description of the error code and suggested troubleshooting steps. Samsung's online support pages may also contain a database of error codes and their meanings.
#
# **Q: Where can I download a copy of my Samsung microwave's user manual?**
# A: You can download a digital copy from Samsung's website using your microwave's model number.
#
# **Q: What should I do if I can't resolve the microwave problem myself?**
# A: Contact Samsung support directly. Have your model and serial numbers ready, and provide a clear description of the problem.  Remember to mention any safety concerns (like arcing).
#
#
# **Safety Considerations:**
#
# **Q: What safety precautions should I take when troubleshooting my Samsung microwave?**
# A:  Never attempt to repair high-voltage components yourself. Always unplug the microwave before attempting any cleaning or troubleshooting.  If you see arcing or sparks, stop using the microwave immediately and contact a qualified technician.
#
#
# --- Structured Question-Answer Pairs (Problem-Solution) ---
# **Problem:** My Samsung microwave isn't heating food.
#
# **Solution:** First, ensure it's properly plugged in and the power outlet is working. Check the circuit breaker/fuse box.  Inspect the power cord for damage. Next, verify the door is fully closed and latched correctly, and check the door seals. If the problem persists, the magnetron, high-voltage diode, or capacitor might be faulty – requiring professional repair.  A malfunctioning control panel could also be the cause.
#
#
# **Problem:** My Samsung microwave won't turn on.
#
# **Solution:** Check the power outlet, circuit breaker, and power cord. See if the control panel lock is enabled (consult your user manual). If completely unresponsive, an internal fuse might have blown, requiring professional repair.
#
#
# **Problem:** I'm seeing arcing or sparks inside my Samsung microwave.
#
# **Solution:**  Remove any metal objects from the microwave. Check the waveguide cover for damage and replace it if necessary. Thoroughly clean the interior to remove food debris.
#
#
# **Problem:** The turntable in my Samsung microwave isn't rotating.
#
# **Solution:** Make sure the turntable is correctly placed on its track and that nothing is obstructing its rotation. If the problem continues, the turntable motor might be faulty.
#
#
# **Problem:** My Samsung microwave is displaying an error code.
#
# **Solution:** Consult your user manual for a description of the error code and troubleshooting steps.  Check Samsung's online support pages for a database of error codes and their meanings.
#
#
# **Problem:** I can't find the solution to my Samsung microwave problem in the provided documentation.
#
# **Solution:** Contact Samsung support directly, providing your microwave's model and serial numbers, and a detailed description of the problem.
#
#
# --- Step-by-Step Question-Answer Pairs ---
# **Microwave Not Heating**
#
# Q: What is the first step to troubleshoot a microwave that's not heating?
# A: Check if the microwave is properly plugged into a working power outlet and check the circuit breaker or fuse box.  Inspect the power cord for damage.
#
# Q: What should I do if the microwave still isn't heating after checking the power supply?
# A: Check the door interlock system to ensure the door is completely closed and latched, and that there are no obstructions.  Also inspect the door seals.
#
# Q: How do I perform step 3 (Magnetron check) in troubleshooting a microwave that's not heating?
# A: If the previous steps failed, the magnetron may be faulty and requires professional repair.  Do not attempt to repair this yourself.
#
# Q:  How do I perform step 4 (High-Voltage Diode and Capacitor check) in troubleshooting a microwave that's not heating?
# A: A faulty high-voltage diode or capacitor can prevent heating.  These components should only be checked and repaired by a qualified technician due to high voltage risks.
#
# Q: What should I check if the power supply, door interlock, magnetron, and high voltage components appear fine, but the microwave still won't heat?
# A: Check the control panel for malfunctions, which could be due to a software glitch or hardware problem.  This may also require professional repair.
#
#
# **Microwave Not Turning On**
#
# Q: What is the first step in troubleshooting a microwave that won't turn on?
# A: Check the power outlet, circuit breaker, and power cord for any issues.
#
# Q: What should I do if the power supply appears to be fine, but the microwave is still not turning on?
# A: Check your user manual to see if the control panel lock feature is enabled and how to disable it.
#
# Q: What is the next step if the control panel lock isn't the issue?
# A: A blown internal fuse may be the problem, requiring professional repair.
#
#
# **Arcing or Sparks Inside the Microwave**
#
# Q: What is the most common cause of arcing or sparks inside a microwave?
# A:  Metal objects placed inside the microwave.  Never put metal in a microwave.
#
# Q:  What should I do if I've removed all metal objects and the arcing persists?
# A: Inspect the waveguide cover for damage and replace it if necessary.  Also, thoroughly clean the inside of the microwave to remove any food debris.
#
# **Turntable Not Rotating**
#
# Q: How do I troubleshoot a turntable that's not rotating?
# A: Ensure the turntable is correctly positioned on its track and that there are no obstructions preventing its rotation.
#
# Q: What should I do if the turntable is correctly placed and there are no obstructions?
# A: The turntable motor might be faulty and require professional repair.
#
#
# **Error Codes Displayed**
#
# Q: What is the first step when an error code is displayed on my Samsung microwave?
# A: Consult your user manual for a description of the error code and suggested troubleshooting steps.
#
# Q: What should I do if the user manual doesn't provide a solution for the error code?
# A: Check Samsung's online support pages for a database of error codes and their meanings.
#
#
# **General Troubleshooting**
#
# Q: What information is crucial when using Samsung's online support resources?
# A: Your microwave's model number.  This is usually found on a sticker inside the door or on the back of the unit.
#
#
# --- FAQ Style Question-Answer Pairs ---
# **Frequently Asked Questions (FAQs) about my Samsung Microwave**
#
# **Q: My Samsung microwave isn't heating my food. What should I do?**
#
# A:  First, check the basics: Is the microwave plugged in securely? Is the circuit breaker tripped or a fuse blown?  Is the door fully closed and the seals clean? If those are all okay, the problem might be with the magnetron (requiring professional repair) or the high-voltage diode/capacitor (also needs a professional).  A faulty control panel is another possibility.
#
# **Q: My Samsung microwave won't turn on at all. What's wrong?**
#
# A: Start by checking the power supply (outlet, breaker, cord). Then, see if the control panel has an accidental lock feature enabled (check your manual). If neither of those is the issue, an internal fuse may have blown, requiring professional service.
#
# **Q: I'm seeing sparks or arcing inside my Samsung microwave. Is this dangerous?**
#
# A: Yes, this is dangerous!  Immediately unplug the microwave.  The cause is usually metal objects inside (never put metal in a microwave!), a damaged waveguide cover (needs replacing), or food debris (clean the interior thoroughly).
#
# **Q: The turntable in my Samsung microwave isn't spinning. How can I fix it?**
#
# A: Make sure the turntable is correctly positioned on its track and nothing is obstructing its rotation.  If it still doesn't turn, the turntable motor may be broken and needs repair.
#
# **Q: My Samsung microwave is displaying an error code. What does it mean?**
#
# A: Consult your user manual for a description of the error code and troubleshooting steps. Samsung's online support pages often have a database of error codes as well.
#
# **Q: Where can I find the user manual for my Samsung microwave if I lost it?**
#
# A: You can download a digital copy from Samsung's website. You'll need your microwave's model number (usually found inside the door or on the back).
#
# **Q: I've tried troubleshooting, but my Samsung microwave is still broken. What should I do now?**
#
# A: Contact Samsung support directly. Be ready to provide your model number and serial number, along with a clear description of the problem.
#
# **Q: How do I find troubleshooting guides or how-to videos for my Samsung microwave?**
#
# A:  Go to Samsung's website and search for support using your microwave's model number.  Their online support pages usually have troubleshooting guides, FAQs, and how-to videos.
#
# **Q: Where can I find the model and serial numbers for my microwave?**
#
# A: These are typically located on a sticker inside the microwave door or on the back of the unit.
#
# **Q:  Is it safe to repair my Samsung microwave myself, especially if it involves high voltage components?**
#
# A:  No, unless you are a qualified technician with experience working with high voltage appliances, you should not attempt repairs involving high-voltage components.  Always prioritize safety and call a professional for repairs if you are unsure.
#
#
# --- Troubleshooting Question-Answer Pairs ---
# ## Samsung Microwave Troubleshooting Q&A
#
# **Power & Heating Issues:**
#
# * **Q: How do I fix my Samsung microwave if it's not heating food?**
#     * **A:** First, check if the microwave is plugged in and the power outlet is working.  Ensure the door is fully closed and the seals are clean. If the problem persists, the magnetron, high-voltage diode, capacitor, or control panel might be faulty—requiring professional repair.
#
# * **Q: What should I do if my Samsung microwave won't turn on?**
#     * **A:** Check the power supply (outlet, circuit breaker, power cord). See if the control panel lock is engaged (consult your manual).  If it's completely unresponsive, an internal fuse might be blown, needing professional attention.
#
# * **Q: Why is my Samsung microwave not heating evenly?**
#     * **A:**  This could be due to uneven food placement, a damaged turntable, or a malfunctioning turntable motor. Ensure the turntable is correctly positioned and rotating freely.  Consider rearranging the food for more even heating.
#
#
# **Internal Issues & Safety:**
#
# * **Q: What should I do if I see arcing or sparks inside my Samsung microwave?**
#     * **A:** Immediately unplug the microwave.  Avoid using it until a professional can inspect it. This is likely caused by metal objects inside, a damaged waveguide cover, or food debris.  Clean the interior thoroughly, and replace any damaged parts.
#
# * **Q: Why is the turntable in my Samsung microwave not rotating?**
#     * **A:** Make sure the turntable is correctly placed on its track and there are no obstructions.  If it still doesn't rotate, the turntable motor might be faulty.
#
#
# **Error Codes & Diagnostics:**
#
# * **Q: What do I do if my Samsung microwave displays an error code?**
#     * **A:** Consult your user manual for a description of the error code and troubleshooting steps. You can also check Samsung's online support pages for a database of error codes and their meanings.  Remember to have your model number ready.
#
#
# **General Troubleshooting:**
#
# * **Q: How do I find troubleshooting information for my specific Samsung microwave model?**
#     * **A:** Locate the model number (usually inside the door or on the back). Use this number to search Samsung's online support pages for specific FAQs, troubleshooting guides, and manuals.
#
# * **Q: Where can I find a downloadable user manual for my Samsung microwave?**
#     * **A:**  Visit Samsung's website and use your model number to download a digital copy of your user manual.
#
# * **Q: When should I contact Samsung support for my microwave?**
#     * **A:** Contact Samsung support if troubleshooting steps from the manual or online resources fail to resolve the problem. Be ready to provide your model and serial numbers, and a clear description of the issue.
#
#
# --- Feature Explanation Question-Answer Pairs ---
# Here are some question-answer pairs based on the provided text, focusing on Samsung microwave features and functionalities:
#
# **Regarding Microwave Operation and Safety:**
#
# * **What is the purpose of the door interlock system in a Samsung microwave?**  The door interlock system is a safety feature that prevents the microwave from operating when the door is open, preventing potential burns or radiation exposure.
#
# * **How does the magnetron work in a Samsung microwave?** The magnetron is the component that generates the microwaves used to heat food.  A malfunctioning magnetron prevents the microwave from heating.
#
# * **What does it mean if I see arcing or sparks inside my Samsung microwave?** Arcing or sparking inside the microwave usually indicates a problem with metal objects being placed inside, a damaged waveguide cover, or food debris causing a short circuit.  This is dangerous and should be addressed immediately.
#
# * **What should I do if my Samsung microwave displays an error code?** Consult the user manual or Samsung's online support pages for your specific model number. These resources usually provide explanations and troubleshooting steps for different error codes.
#
# * **How does the turntable in a Samsung microwave work, and what should I do if it isn't rotating?** The turntable rotates to distribute microwaves evenly throughout the food. If it's not rotating, check if it's properly placed on its track and free from obstructions. A faulty turntable motor may require professional repair.
#
#
# **Regarding Troubleshooting and Support Resources:**
#
# * **What is the importance of having the model number of my Samsung microwave when seeking support?** The model number is crucial for accessing specific information, manuals, troubleshooting guides, and FAQs related to your particular microwave model on Samsung's website.
#
# * **What resources are available on Samsung's website to help troubleshoot microwave problems?** Samsung's website offers dedicated support pages with FAQs, troubleshooting guides, how-to videos, software updates (if applicable), and downloadable manuals.
#
# * **What are some common reasons why a Samsung microwave might not heat food?**  Potential causes include power supply issues (outlet, circuit breaker, cord), problems with the door interlock system, a faulty magnetron,  high-voltage diode or capacitor problems, or control panel issues.
#
# * **What should I check if my Samsung microwave isn't turning on?** First, check the power supply (outlet, circuit breaker, cord). Then, check your user manual to see if the control panel lock is enabled. Finally, an internal fuse may have blown, requiring professional repair.
#
# * **What information should I be prepared to provide when contacting Samsung support for microwave repair?**  You should have the model number, serial number, and a clear description of the problem you are experiencing.
#
#
# These question-answer pairs directly address features and how they function based on the provided support document text.  They focus on understanding the purpose and operation of specific microwave components and troubleshooting steps.
#
#
# --- Setup & Configuration Question-Answer Pairs ---
# The provided text focuses on troubleshooting rather than initial setup.  Samsung microwaves don't have extensive configuration options beyond initial power connection.  Therefore, the questions below are limited, focusing on the only setup aspect mentioned:  power connection and perhaps initial checks related to the turntable.
#
# **Q&A Pairs:**
#
# * **How do I set up my new Samsung microwave?**  A:  Ensure the microwave is plugged into a functioning power outlet. Check the power cord for damage. Place the turntable correctly on its track. Consult the user manual for additional model-specific instructions.
#
# * **What are the initial setup steps for a Samsung microwave?** A: Plug the microwave into a working power outlet, ensuring the power cord isn't damaged.  Check that the turntable is properly seated on its rotating track.  Refer to the included user manual for model-specific setup information.
#
# * **How do I configure the turntable in my Samsung microwave?** A: The turntable generally doesn't require configuration.  Simply ensure it's correctly positioned on its track.  If it isn't rotating, check for obstructions.  If it still doesn't work, refer to the troubleshooting section of the user manual.
#
#
# There are no other setup or configuration options detailed in the provided text.  The document primarily addresses troubleshooting existing problems.

# %%
import google.generativeai as genai

# Configure API key for Google Generative AI
# apikey=userdata.get('GOOGLE_API_KEY')
# genai.configure(api_key=apikey)

# Content to generate question-answer pairs from
content=generated_text
# Specify the number of QA pairs you want
num_pairs = 3

# Create the GenerativeModel instance
model = genai.GenerativeModel('gemini-1.5-flash')

# Generate content with the specified prompt
response = model.generate_content(
    f"Generate {num_pairs} question-answer pairs from the following content. Provide the output in the form Q: question text\n A: answer text\n\nContent: {content}"
)

# Print the generated content after removing Markdown formatting
output = response.text.replace('*', '').replace('#', '')
print(output)
# Out:
# Q: What are the key resources available in Samsung's microwave support documentation?
# A: Samsung's support resources include user manuals providing detailed instructions and safety information; online support pages with FAQs, troubleshooting guides, and how-to videos; and community forums where users can share experiences and find solutions.
#
# Q: How can I troubleshoot a Samsung microwave that's not heating?
# A: First, check the power supply (outlet, circuit breaker, cord).  Then, ensure the door is fully closed and the door seals are clean.  If the problem persists, the magnetron, high-voltage diode, capacitor, or control panel may be faulty, requiring professional repair.
#
# Q: What should I do if my Samsung microwave displays an error code?
# A: Consult your user manual for a description of the error code and troubleshooting steps. You can also check Samsung's online support pages for a database of error codes and their meanings.

# %%
import google.generativeai as genai
import json

# Configure API key for Google Generative AI (ensure this is set up correctly)
# apikey = userdata.get('GOOGLE_API_KEY')
# genai.configure(api_key=apikey)

def generate_qa_pairs(content: str, num_pairs: int = 3, format_output: str = 'plain') -> str | list[dict]:
    """
    Generates question-answer pairs from the given text content using a generative AI model.

    This function leverages Google's Gemini model to analyze the provided text and extract
    meaningful question-answer pairs. It offers flexibility in terms of the number of pairs
    generated and the output format (plain text or JSON).

    Args:
        content: The string containing the text from which to generate question-answer pairs.
        num_pairs: An integer specifying the desired number of question-answer pairs to generate.
                   Defaults to 3.
        format_output: A string indicating the desired output format.
                       - 'plain': Outputs the question-answer pairs in a human-readable plain text format.
                       - 'json': Outputs the question-answer pairs as a JSON array of objects.
                       Defaults to 'plain'.

    Returns:
        str | list[dict]: The generated question-answer pairs. Returns a string if `format_output` is 'plain',
                    and a list of dictionaries if `format_output` is 'json'.

    Raises:
        TypeError: If `content` is not a string or `num_pairs` is not an integer.
        ValueError: If `num_pairs` is not a positive integer or `format_output` is not 'plain' or 'json'.
        RuntimeError: If an error occurs during the interaction with the generative AI model.

    Example Usage:
        # Generate 5 QA pairs in plain text format
        plain_output = generate_qa_pairs("The capital of France is Paris.", num_pairs=5, format_output='plain')
        print(plain_output)

        # Generate 2 QA pairs in JSON format
        json_output = generate_qa_pairs("The Earth revolves around the Sun.", num_pairs=2, format_output='json')
        print(json_output)
    """

    # Input validation
    if not isinstance(content, str):
        raise TypeError("content must be a string.")
    if not isinstance(num_pairs, int):
        raise TypeError("num_pairs must be an integer.")
    if num_pairs <= 0:
        raise ValueError("num_pairs must be a positive integer.")
    if format_output not in ['plain', 'json']:
        raise ValueError("format_output must be either 'plain' or 'json'.")

    try:
        # Initialize the generative model
        model = genai.GenerativeModel('gemini-1.5-flash')

        # Construct the prompt for plain text output
        prompt = f"Generate {num_pairs} question-answer pairs from the following content.\n\nContent:\n{content}\n\nFormat the output as follows:\nQ: [question]\nA: [answer]"

        response = model.generate_content(prompt)
        output_text = response.text.replace('*', '').replace('#', '')  # Remove potential markdown artifacts

        if format_output == 'plain':
            return output_text
        elif format_output == 'json':
            # Split the plain text into lines
            lines = output_text.strip().split('\n')
            qa_pairs = []
            i = 0
            while i < len(lines):
                if lines[i].startswith('Q:'):
                    question = lines[i][2:].strip()
                    if i + 1 < len(lines) and lines[i + 1].startswith('A:'):
                        answer = lines[i + 1][2:].strip()
                        qa_pairs.append({"question": question, "answer": answer})
                        i += 2
                    else:
                        # No corresponding answer found
                        i += 1
                else:
                    i += 1
            return qa_pairs

    except Exception as e:
        raise RuntimeError(f"An error occurred during QA pair generation: {e}")

# Example usage with explanations
content = generated_text

# Generate QA pairs in plain text format
print("--- Generating QA pairs in plain text format ---")
plain_qa_pairs = generate_qa_pairs(content, num_pairs=3, format_output='plain')
print(plain_qa_pairs)
# Explanation:
# The 'generate_qa_pairs' function is called with the 'content', requesting 4 QA pairs,
# and specifying 'plain' as the output format. The function will return a string
# where each question and answer are presented in a human-readable format.

# Generate QA pairs in JSON format
print("\n--- Generating QA pairs in JSON format ---")
json_qa_pairs = generate_qa_pairs(content, num_pairs=5, format_output='json')
# print(json_qa_pairs)
# Assuming json_qa_pairs is your list of dictionaries
# Convert the list of dictionaries to a formatted JSON string
formatted_json = json.dumps(json_qa_pairs, indent=4)

# Print the formatted JSON string
print(formatted_json)
# Explanation:
# Here, the function is called again with the same 'content', but this time requesting 2 QA pairs
# and setting 'format_output' to 'json'. The function generates plain text QA pairs and then
# converts them into a list of dictionaries in JSON format.
# Out:
# --- Generating QA pairs in plain text format ---
# Q: What are the key resources available in Samsung's microwave support documentation?
# A: Samsung offers user manuals, online support pages (including FAQs, troubleshooting guides, how-to videos, and software updates), and community forums where users can share experiences and find solutions.
#
# Q: What are the first steps to take if my Samsung microwave is not heating?
# A: First, check the power supply (outlet, circuit breaker, power cord).  Then, ensure the door is properly closed and the door seals are clean and intact.  If the problem persists, the magnetron or other high-voltage components may be faulty and require professional repair.
#
# Q: How can I troubleshoot error codes displayed on my Samsung microwave?
# A: Consult your user manual for a description of the error code and troubleshooting steps.  You can also check Samsung's online support pages for a database of error codes and their meanings.  The model number of your microwave is crucial for accessing this information.
#
#
# --- Generating QA pairs in JSON format ---
# [
#     {
#         "question": "What are the primary resources available through Samsung for troubleshooting microwave issues?",
#         "answer": "Samsung offers user manuals, online support pages (including FAQs, troubleshooting guides, and how-to videos), and community forums for troubleshooting microwave problems."
#     },
#     {
#         "question": "My Samsung microwave isn't heating. What are some initial troubleshooting steps I should take?",
#         "answer": "First, check the power supply (outlet, circuit breaker, power cord).  Then, ensure the microwave door is completely closed and the door seals are clean and intact.  If these don't solve the problem, the magnetron or other high-voltage components may be faulty, requiring professional repair."
#     },
#     {
#         "question": "My Samsung microwave won't turn on. What are the possible causes?",
#         "answer": "Possible causes include a problem with the power supply (outlet, breaker, cord), an enabled control panel lock, or a blown internal fuse (requiring professional repair)."
#     },
#     {
#         "question": "I'm getting arcing or sparks inside my Samsung microwave. What should I do?",
#         "answer": "Remove any metal objects from the microwave.  Inspect the waveguide cover for damage and replace it if necessary. Thoroughly clean the interior of the microwave to remove any food debris that might be causing the arcing."
#     },
#     {
#         "question": "How can I find information about a specific error code displayed on my Samsung microwave?",
#         "answer": "Consult your user manual for a description of the error code and troubleshooting steps.  Alternatively, check Samsung's online support pages for a database of error codes and their meanings.  Providing your microwave's model number will help you find the correct information."
#     }
# ]

# %%
import google.generativeai as genai
import json
import re

def clean_json_response(response_text: str) -> str:
    """
    Clean and extract valid JSON from the model's response text.

    Args:
        response_text: Raw response text from the model

    Returns:
        Cleaned JSON string
    """
    # Find JSON array pattern (anything between [ and ])
    json_match = re.search(r'\[[\s\S]*\]', response_text)
    if json_match:
        json_str = json_match.group(0)
        # Remove any markdown code block markers
        json_str = re.sub(r'```json|```', '', json_str)
        # Clean up any remaining whitespace
        json_str = json_str.strip()
        return json_str
    return response_text

def generate_qa_pairs(content: str, num_pairs: int = 3, format_output: str = 'plain') -> str | list[dict]:
    """
    Generates question-answer pairs from the given text content using a generative AI model.

    Args:
        content: The string containing the text from which to generate question-answer pairs.
        num_pairs: An integer specifying the desired number of question-answer pairs to generate.
                   Defaults to 3.
        format_output: Output format ('plain' or 'json'). Defaults to 'plain'.

    Returns:
        str | list[dict]: The generated question-answer pairs.

    Raises:
        TypeError: If input types are invalid
        ValueError: If input values are invalid
        RuntimeError: If an error occurs during generation
    """
    # Input validation
    if not isinstance(content, str):
        raise TypeError("content must be a string.")
    if not isinstance(num_pairs, int):
        raise TypeError("num_pairs must be an integer.")
    if num_pairs <= 0:
        raise ValueError("num_pairs must be a positive integer.")
    if format_output not in ['plain', 'json']:
        raise ValueError("format_output must be either 'plain' or 'json'.")

    try:
        # Initialize the generative model
        model = genai.GenerativeModel('gemini-1.5-flash')

        if format_output == 'plain':
            prompt = f"""Generate {num_pairs} question-answer pairs from the following content.
            Format each pair exactly as shown:
            Q: [question]
            A: [answer]

            Content:
            {content}"""

            response = model.generate_content(prompt)
            output_text = response.text.strip()
            # Clean up potential markdown artifacts while preserving Q: and A: format
            output_text = re.sub(r'[*#`]', '', output_text)
            return output_text

        else:  # json format
            prompt = f"""Generate exactly {num_pairs} question-answer pairs from this content and return them in valid JSON format.
            The response must be a JSON array containing objects with 'question' and 'answer' keys.
            Do not include any other text, explanations, or markdown formatting.

            Content:
            {content}

            Required JSON structure:
            [
              {{
                "question": "Sample question?",
                "answer": "Sample answer."
              }}
            ]"""

            max_retries = 3
            for attempt in range(max_retries):
                try:
                    response = model.generate_content(prompt)

                    if not response.text or not response.text.strip():
                        if attempt == max_retries - 1:
                            return []
                        continue

                    # Clean and extract JSON from response
                    cleaned_json = clean_json_response(response.text)

                    # Parse and validate JSON structure
                    qa_json = json.loads(cleaned_json)
                    if not isinstance(qa_json, list):
                        raise ValueError("Expected JSON array")

                    # Validate each QA pair
                    validated_pairs = []
                    for item in qa_json:
                        if isinstance(item, dict) and "question" in item and "answer" in item:
                            validated_pairs.append({
                                "question": str(item["question"]).strip(),
                                "answer": str(item["answer"]).strip()
                            })

                    # If we got valid pairs, return them
                    if validated_pairs:
                        return validated_pairs[:num_pairs]  # Ensure we don't return more than requested

                except (json.JSONDecodeError, ValueError) as e:
                    if attempt == max_retries - 1:
                        print(f"Failed to generate valid JSON after {max_retries} attempts. Last error: {e}")
                        print(f"Last response received:\n{response.text}")
                        return []
                    continue

    except Exception as e:
        raise RuntimeError(f"An error occurred during QA pair generation: {e}")


# Example usage
# content = """
# Title: Fixing Heating Issues in Samsung Microwave Ovens
# [your content here]
# """

# Generate plain text QA pairs
plain_qa = generate_qa_pairs(content, num_pairs=3, format_output='plain')
print(plain_qa)

# Generate JSON QA pairs
json_qa = generate_qa_pairs(content, num_pairs=4, format_output='json')
print(json.dumps(json_qa, indent=2))
# Out:
# Q: What are the key resources available through Samsung for troubleshooting microwave issues?
# A: Samsung offers user manuals, online support pages (including FAQs, troubleshooting guides, and how-to videos), and community forums where users can share experiences and find solutions.
#
# Q: What are some common problems encountered with Samsung microwaves, and what initial troubleshooting steps can be taken?
# A: Common issues include the microwave not heating (check power supply, door interlock, and magnetron), not turning on (check power, control panel lock, and internal fuse), arcing/sparks (check for metal objects, damaged waveguide cover, and food debris), the turntable not rotating (check track and motor), and error codes (consult user manual or online support).
#
# Q:  How can I effectively utilize Samsung's online support resources to troubleshoot my microwave?
# A:  To effectively use Samsung's online resources, you need your microwave's model number. This allows you to access downloadable manuals, troubleshooting guides, FAQs, and how-to videos specific to your model.
# [
#   {
#     "question": "What is the first step to troubleshoot a Samsung microwave that is not heating?",
#     "answer": "Ensure the microwave is properly plugged into a functioning power outlet and check the circuit breaker or fuse box."
#   },
#   {
#     "question": "Why might my Samsung microwave not turn on?",
#     "answer": "Possible causes include a power supply issue, an enabled control panel lock, or a blown internal fuse."
#   },
#   {
#     "question": "What should I do if I see arcing or sparks inside my Samsung microwave?",
#     "answer": "Avoid using metal objects inside the microwave, check the waveguide cover for damage, and thoroughly clean any food debris."
#   },
#   {
#     "question": "How can I find troubleshooting information for a specific error code displayed on my Samsung microwave?",
#     "answer": "Consult the user manual or Samsung's online support pages for your microwave model."
#   }
# ]

# %%
# !mkdir /content/results
# !wget https://github.com/navneetkrc/Open_LLM_Apps/raw/main/sample%20txt%20files/Agentic%20rag%20Survey%20paper.pdf
# Out:
# --2025-01-24 17:55:54--  https://github.com/navneetkrc/Open_LLM_Apps/raw/main/sample%20txt%20files/Agentic%20rag%20Survey%20paper.pdf
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/navneetkrc/Open_LLM_Apps/main/sample%20txt%20files/Agentic%20rag%20Survey%20paper.pdf [following]
# --2025-01-24 17:55:55--  https://raw.githubusercontent.com/navneetkrc/Open_LLM_Apps/main/sample%20txt%20files/Agentic%20rag%20Survey%20paper.pdf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14826884 (14M) [application/octet-stream]
# Saving to: ‘Agentic rag Survey paper.pdf’
#
# Agentic rag Survey  100%[===================>]  14.14M  --.-KB/s    in 0.1s
#
# 2025-01-24 17:55:55 (114 MB/s) - ‘Agentic rag Survey paper.pdf’ saved [14826884/14826884]

# %%
#generated qa pairs saved in text file
import google.generativeai as genai
import fitz  # PyMuPDF for PDF text extraction
import json
import os
import time

## Configure API key for Google Generative AI
# apikey=userdata.get('GOOGLE_API_KEY')
# genai.configure(api_key=apikey)

def extract_text_from_pdf(pdf_path):
    """Extract text from a PDF file."""
    text = ""
    try:
        # Open the PDF file
        pdf_document = fitz.open(pdf_path)

        # Extract text from each page
        for page_num in range(len(pdf_document)):
            page = pdf_document.load_page(page_num)
            text += page.get_text()

        pdf_document.close()
        return text
    except Exception as e:
        print(f"Error extracting text from PDF: {e}")
        return ""

def generate_qa_pairs(content, num_pairs=3, format_output='plain', retry_attempts=3, save_to_file=None):
    """
    Generate question-answer pairs from the provided content.

    Parameters:
    - content (str): The text content to generate QA pairs from.
    - num_pairs (int): The number of QA pairs to generate.
    - format_output (str): The format for output ('plain' or 'json').
    - retry_attempts (int): Number of retry attempts in case of API failure.
    - save_to_file (str): Path to file where output will be saved.

    Returns:
    - str or dict: The generated QA pairs in the specified format.
    """
    if not isinstance(num_pairs, int) or num_pairs <= 0:
        raise ValueError("num_pairs must be a positive integer.")

    if format_output not in ['plain', 'json']:
        raise ValueError("format_output must be 'plain' or 'json'.")

    attempts = 0
    while attempts < retry_attempts:
        try:
            # Create the GenerativeModel instance
            model = genai.GenerativeModel('gemini-1.5-flash')

            # Generate content with the specified prompt
            prompt = (f"Generate {num_pairs} question-answer pairs from the following content. "
                      f"Provide the output in the form Q: question text\n A: answer text\n\nContent: {content}")
            response = model.generate_content(prompt)

            # Clean up the generated content
            output = response.text.replace('*', '').replace('#', '')

            # Format the output based on user preference
            if format_output == 'json':
                qa_pairs = [line.strip() for line in output.split('\n') if line.strip()]
                qa_json = [{'question': qa_pairs[i], 'answer': qa_pairs[i+1]} for i in range(0, len(qa_pairs), 2)]
                output = json.dumps(qa_json, indent=2)

            if save_to_file:
                with open(save_to_file, 'w') as file:
                    file.write(output)
                print(f"Output saved to {save_to_file}")

            return output

        except Exception as e:
            attempts += 1
            print(f"Attempt {attempts} failed: {e}")
            if attempts < retry_attempts:
                time.sleep(2)  # Wait before retrying

    return "Failed to generate QA pairs after several attempts."

# Example usage
#path of pdf
pdf_path = r"/content/Agentic rag Survey paper.pdf"
num_pairs = 3 #no of qa pairs we want
format_output = 'plain'  # Change to 'json' for JSON output
save_to_file = r"/content/results/text.txt"  # Specify the file path to save output

# Extract text from PDF
content = extract_text_from_pdf(pdf_path)

# Generate and print QA pairs
if content:
    qa_pairs_output = generate_qa_pairs(content, num_pairs, format_output, save_to_file=save_to_file)
    print(qa_pairs_output)
else:
    print("No content extracted from PDF.")
# Out:
# Output saved to /content/results/text.txt
# Q: What is Agentic Retrieval-Augmented Generation (Agentic RAG), and how does it differ from traditional RAG?
# A: Agentic RAG is a paradigm that integrates autonomous AI agents into the Retrieval-Augmented Generation (RAG) pipeline.  Unlike traditional RAG, which has static workflows and limited adaptability, Agentic RAG uses agents to dynamically manage retrieval strategies, iteratively refine contextual understanding, and adapt workflows to complex tasks, resulting in greater flexibility and scalability.
#
# Q: What are the four key agentic patterns that guide the behavior of agents in Agentic RAG systems?
# A: The four key agentic patterns are Reflection (iteratively evaluating and refining outputs), Planning (autonomously decomposing complex tasks), Tool Use (interacting with external tools and resources), and Multi-Agent Collaboration (distributing tasks among specialized agents).
#
# Q: What are some of the key applications of Agentic RAG systems across various industries?
# A: Agentic RAG systems find applications in customer support (providing real-time, personalized responses), healthcare (integrating patient data with medical research), finance (delivering real-time market insights), education (creating personalized learning experiences), and legal workflows (automating contract analysis).  They also show promise in creative industries and multimodal workflows (combining text, images, and videos).

# %%
import google.generativeai as genai
import fitz  # PyMuPDF for PDF text extraction
import json
import os
import time

# !wget https://github.com/navneetkrc/Open_LLM_Apps/raw/main/sample%20txt%20files/Agentic%20rag%20Survey%20paper.pdf
## Configure API key for Google Generative AI
# apikey=userdata.get('GOOGLE_API_KEY')
# genai.configure(api_key=apikey)

def extract_text_from_pdf(pdf_path):
    """Extract text from a PDF file."""
    text = ""
    try:
        # Open the PDF file
        pdf_document = fitz.open(pdf_path)

        # Extract text from each page
        for page_num in range(len(pdf_document)):
            page = pdf_document.load_page(page_num)
            text += page.get_text()

        pdf_document.close()
        return text
    except Exception as e:
        print(f"Error extracting text from PDF: {e}")
        return ""

def generate_qa_pairs(content, num_pairs=3, format_output='plain', retry_attempts=3, save_to_file=None):
    """
    Generate question-answer pairs from the provided content.

    Parameters:
    - content (str): The text content to generate QA pairs from.
    - num_pairs (int): The number of QA pairs to generate.
    - format_output (str): The format for output ('plain' or 'json').
    - retry_attempts (int): Number of retry attempts in case of API failure.
    - save_to_file (str): Path to file where output will be saved.

    Returns:
    - str or dict: The generated QA pairs in the specified format.
    """
    if not isinstance(num_pairs, int) or num_pairs <= 0:
        raise ValueError("num_pairs must be a positive integer.")

    if format_output not in ['plain', 'json']:
        raise ValueError("format_output must be 'plain' or 'json'.")

    attempts = 0
    while attempts < retry_attempts:
        try:
            # Create the GenerativeModel instance
            model = genai.GenerativeModel('gemini-1.5-flash')

            # Generate content with the specified prompt
            prompt = (f"Generate {num_pairs} question-answer pairs from the following content. "
                      f"Provide the output in the form Q: question text\n A: answer text\n\nContent: {content}")
            response = model.generate_content(prompt)

            # Clean up the generated content
            output = response.text.replace('*', '').replace('#', '')

            # Split the output into questions and answers
            questions = []
            answers = []
            lines = output.split('\n')
            for line in lines:
                if line.startswith('Q:'):
                    questions.append(line.replace('Q:', '').strip())
                elif line.startswith('A:'):
                    answers.append(line.replace('A:', '').strip())

            # Ensure the number of questions and answers matches num_pairs
            if len(questions) > num_pairs:
                questions = questions[:num_pairs]
            if len(answers) > num_pairs:
                answers = answers[:num_pairs]

            # Format the output based on user preference
            if format_output == 'json':
                qa_json = [{'question': questions[i], 'answer': answers[i]} for i in range(len(questions))]
                output = json.dumps(qa_json, indent=2)
            else:  # plain text
                output = "\n".join([f"Q{i+1}: {questions[i]}\nA{i+1}: {answers[i]}" for i in range(len(questions))])

            if save_to_file:
                with open(save_to_file, 'w') as file:
                    file.write(output)
                print(f"Output saved to {save_to_file}")

            return output

        except Exception as e:
            attempts += 1
            print(f"Attempt {attempts} failed: {e}")
            if attempts < retry_attempts:
                time.sleep(2)  # Wait before retrying

    return "Failed to generate QA pairs after several attempts."

# Example usage
pdf_path = r"/content/Agentic rag Survey paper.pdf"
num_pairs = 3
format_output = 'plain'  # Change to 'json' for JSON output
save_to_file = r"/content/results/text.txt"  # Specify the file path to save output

# Extract text from PDF
content = extract_text_from_pdf(pdf_path)

# Generate and print QA pairs
if content:
    qa_pairs_output = generate_qa_pairs(content, num_pairs, format_output, save_to_file=save_to_file)
    print(qa_pairs_output)
else:
    print("No content extracted from PDF.")
# Out:
# Output saved to /content/results/text.txt
# Q1: What are the limitations of Large Language Models (LLMs) that led to the development of Retrieval-Augmented Generation (RAG)?
# A1: LLMs rely on static training data, resulting in outdated information, hallucinated responses, and an inability to adapt to dynamic, real-world scenarios.  This necessitates systems that integrate real-time data and dynamically refine responses to maintain accuracy and relevance.
# Q2: What is Agentic Retrieval-Augmented Generation (Agentic RAG), and how does it improve upon traditional RAG?
# A2: Agentic RAG integrates autonomous AI agents into the RAG pipeline. These agents use agentic design patterns (reflection, planning, tool use, multi-agent collaboration) to dynamically manage retrieval strategies, refine contextual understanding, and adapt workflows for complex tasks.  This surpasses traditional RAG's limitations of static workflows and inability to handle multi-step reasoning.
# Q3: What are some key applications of Agentic RAG across different industries?
# A3: Agentic RAG has applications in customer support (providing real-time, personalized responses), healthcare (integrating patient data with medical research for personalized medicine), finance (providing real-time market insights and risk analysis), education (creating adaptive learning experiences), and legal workflows (automating contract analysis).  It also shows promise in creative industries with graph-enhanced multimodal workflows.

# %%
import google.generativeai as genai
import fitz  # PyMuPDF
import json
import os
import time
from typing import Union, List, Dict, Optional
from pathlib import Path

class PDFQAGenerator:
    """
    A class to extract text from PDFs and generate question-answer pairs using Google's Gemini model.
    """

    def __init__(self, model_name: str = 'gemini-1.5-flash'):
        """
        Initialize the QA Generator with specified model.

        Args:
            model_name: Name of the Gemini model to use
        """
        self.model = genai.GenerativeModel(model_name)

    def extract_text_from_pdf(self, pdf_path: Union[str, Path]) -> str:
        """
        Extract text content from a PDF file.

        Args:
            pdf_path: Path to the PDF file

        Returns:
            Extracted text from the PDF

        Raises:
            FileNotFoundError: If PDF file doesn't exist
            ValueError: If PDF is empty or corrupted
        """
        pdf_path = Path(pdf_path)
        if not pdf_path.exists():
            raise FileNotFoundError(f"PDF file not found: {pdf_path}")

        try:
            with fitz.open(pdf_path) as pdf:
                if len(pdf) == 0:
                    raise ValueError("PDF file is empty")

                # Extract text from all pages with proper spacing
                text = " ".join(
                    page.get_text().replace('\n', ' ').strip()
                    for page in pdf
                )
                return text.strip()

        except Exception as e:
            raise ValueError(f"Error processing PDF: {str(e)}")

    def _parse_qa_response(self, response_text: str, num_pairs: int) -> List[Dict[str, str]]:
        """
        Parse the model's response into structured QA pairs.

        Args:
            response_text: Raw text response from the model
            num_pairs: Number of desired QA pairs

        Returns:
            List of dictionaries containing questions and answers
        """
        qa_pairs = []
        current_pair = {}

        for line in response_text.split('\n'):
            line = line.strip()
            if not line:
                continue

            if line.startswith('Q:'):
                if current_pair.get('question'):  # Save previous pair
                    qa_pairs.append(current_pair)
                    current_pair = {}
                current_pair['question'] = line[2:].strip()
            elif line.startswith('A:') and 'question' in current_pair:
                current_pair['answer'] = line[2:].strip()

        # Add the last pair if complete
        if len(current_pair) == 2:
            qa_pairs.append(current_pair)

        return qa_pairs[:num_pairs]  # Ensure we don't exceed requested pairs

    def generate_qa_pairs(
        self,
        content: str,
        num_pairs: int = 3,
        format_output: str = 'plain',
        retry_attempts: int = 3,
        save_path: Optional[Union[str, Path]] = None
    ) -> Union[str, List[Dict[str, str]]]:
        """
        Generate question-answer pairs from text content.

        Args:
            content: Source text to generate QA pairs from
            num_pairs: Number of QA pairs to generate
            format_output: Output format ('plain' or 'json')
            retry_attempts: Number of retries on failure
            save_path: Optional path to save results

        Returns:
            Generated QA pairs in requested format

        Raises:
            ValueError: For invalid arguments
            RuntimeError: For generation failures
        """
        if not content.strip():
            raise ValueError("Content cannot be empty")
        if not isinstance(num_pairs, int) or num_pairs < 1:
            raise ValueError("num_pairs must be a positive integer")
        if format_output not in {'plain', 'json'}:
            raise ValueError("format_output must be 'plain' or 'json'")

        prompt = f"""Generate {num_pairs} question-answer pairs from this content.
        Make questions diverse and cover different aspects of the content.
        Format each pair exactly as:
        Q: [Question]
        A: [Answer]

        Content: {content[:8000]}  # Limit content length for API
        """

        for attempt in range(retry_attempts):
            try:
                response = self.model.generate_content(prompt)
                qa_pairs = self._parse_qa_response(response.text, num_pairs)

                if not qa_pairs:
                    continue  # Retry if no valid pairs were parsed

                # Format output
                if format_output == 'json':
                    output = qa_pairs
                else:
                    output = '\n\n'.join(
                        f"Q: {pair['question']}\nA: {pair['answer']}"
                        for pair in qa_pairs
                    )

                # Save if requested
                if save_path:
                    save_path = Path(save_path)
                    save_path.parent.mkdir(parents=True, exist_ok=True)
                    with save_path.open('w', encoding='utf-8') as f:
                        if format_output == 'json':
                            json.dump(output, f, indent=2)
                        else:
                            f.write(output)

                return output

            except Exception as e:
                if attempt == retry_attempts - 1:
                    raise RuntimeError(f"Failed to generate QA pairs: {str(e)}")
                time.sleep(2)  # Wait before retry

def main():
    """Example usage of the PDFQAGenerator."""
    # Initialize generator
    generator = PDFQAGenerator()

    # Example configuration
    pdf_path = "/content/Agentic rag Survey paper.pdf"
    output_path = "qa_output.txt"

    try:
        # Extract text and generate QA pairs
        content = generator.extract_text_from_pdf(pdf_path)
        qa_pairs = generator.generate_qa_pairs(
            content=content,
            num_pairs=5,
            format_output='json',
            save_path=output_path
        )
        print(json.dumps(qa_pairs, indent=2))

    except Exception as e:
        print(f"Error: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# [
#   {
#     "question": "What is the primary limitation of Large Language Models (LLMs) addressed by Retrieval-Augmented Generation (RAG)?",
#     "answer": "LLMs rely on static training data, resulting in outdated information, hallucinated responses, and an inability to adapt to dynamic, real-world scenarios. RAG addresses this by integrating real-time data retrieval."
#   },
#   {
#     "question": "How does Agentic RAG improve upon traditional RAG systems?",
#     "answer": "Agentic RAG embeds autonomous AI agents into the RAG pipeline, enabling dynamic retrieval strategies, iterative refinement of contextual understanding, and adaptable workflows to handle complex tasks, unlike the static workflows of traditional RAG."
#   },
#   {
#     "question": "What are some key agentic design patterns leveraged by Agentic RAG systems?",
#     "answer": "Agentic RAG systems utilize reflection, planning, tool use, and multi-agent collaboration to manage dynamic workflows and solve intricate problems."
#   },
#   {
#     "question": "In what industries are Agentic RAG systems finding applications, according to the survey?",
#     "answer": "The survey highlights applications of Agentic RAG in healthcare, finance, and education."
#   },
#   {
#     "question": "What are some of the challenges discussed in the survey regarding the implementation and scaling of Agentic RAG systems?",
#     "answer": "The survey addresses challenges in scaling Agentic RAG systems, ensuring ethical decision-making, and optimizing performance for real-world applications."
#   }
# ]

# %%
# Initialize the generator
generator = PDFQAGenerator()

# Generate QA pairs from PDF
try:
    # Extract text
    content = generator.extract_text_from_pdf("/content/Agentic rag Survey paper.pdf")

    # Generate QA pairs
    qa_pairs = generator.generate_qa_pairs(
        content=content,
        num_pairs=5,
        format_output='json',
        save_path='output.json'
    )
    print(json.dumps(qa_pairs, indent=2))
except Exception as e:
    print(f"Error: {str(e)}")
# Out:
# [
#   {
#     "question": "What is the main limitation of Large Language Models (LLMs) addressed by Retrieval-Augmented Generation (RAG)?",
#     "answer": "LLMs rely on static training data, resulting in outdated information, hallucinated responses, and an inability to adapt to dynamic, real-world scenarios. RAG addresses this by integrating real-time data retrieval."
#   },
#   {
#     "question": "How does Agentic RAG improve upon traditional RAG systems?",
#     "answer": "Agentic RAG embeds autonomous AI agents into the RAG pipeline, enabling dynamic retrieval strategies, iterative refinement of contextual understanding, and adaptable workflows for complex tasks.  Traditional RAG systems are limited by static workflows and lack adaptability for multi-step reasoning."
#   },
#   {
#     "question": "What are some key agentic design patterns utilized in Agentic RAG systems?",
#     "answer": "Agentic RAG systems leverage reflection, planning, tool use, and multi-agent collaboration to manage dynamic workflows and solve complex problems."
#   },
#   {
#     "question": "What are some application areas highlighted for Agentic RAG in the survey?",
#     "answer": "The survey highlights applications of Agentic RAG in healthcare, finance, and education."
#   },
#   {
#     "question": "What are the three core components of a Retrieval-Augmented Generation (RAG) system?",
#     "answer": "The three core components are Retrieval (querying external data sources), Augmentation (processing and summarizing retrieved data), and Generation (combining retrieved information with LLM generation)."
#   }
# ]

# %%
#separate qa pairs
import google.generativeai as genai
import fitz  # PyMuPDF for PDF text extraction
import json
import os
import time

## Configure API key for Google Generative AI
# apikey=userdata.get('GOOGLE_API_KEY')
# genai.configure(api_key=apikey)

def extract_text_from_pdf(pdf_path):
    """Extract text from a PDF file."""
    text = ""
    try:
        # Open the PDF file
        pdf_document = fitz.open(pdf_path)

        # Extract text from each page
        for page_num in range(len(pdf_document)):
            page = pdf_document.load_page(page_num)
            text += page.get_text()

        pdf_document.close()
        return text
    except Exception as e:
        print(f"Error extracting text from PDF: {e}")
        return ""

def generate_qa_pairs(content, num_pairs=3, format_output='plain', retry_attempts=3, save_to_file=None):
    """
    Generate question-answer pairs from the provided content.

    Parameters:
    - content (str): The text content to generate QA pairs from.
    - num_pairs (int): The number of QA pairs to generate.
    - format_output (str): The format for output ('plain' or 'json').
    - retry_attempts (int): Number of retry attempts in case of API failure.
    - save_to_file (str): Path to file where output will be saved.

    Returns:
    - str or dict: The generated QA pairs in the specified format.
    """
    if not isinstance(num_pairs, int) or num_pairs <= 0:
        raise ValueError("num_pairs must be a positive integer.")

    if format_output not in ['plain', 'json']:
        raise ValueError("format_output must be 'plain' or 'json'.")

    attempts = 0
    while attempts < retry_attempts:
        try:
            # Create the GenerativeModel instance
            model = genai.GenerativeModel('gemini-1.5-flash')

            # Generate content with the specified prompt
            prompt = (f"Generate {num_pairs} question-answer pairs from the following content. "
                      f"Provide all questions first and then all answers, separated by new lines. "
                      f"Output in the form Q: question text\nA: answer text\n\nContent: {content}")
            response = model.generate_content(prompt)

            # Clean up the generated content
            output = response.text.replace('*', '').replace('#', '')

            # Split the output into questions and answers
            lines = output.split('\n')
            questions = [line.replace('Q:', '').strip() for line in lines if line.startswith('Q:')]
            answers = [line.replace('A:', '').strip() for line in lines if line.startswith('A:')]

            # Ensure the number of questions and answers matches num_pairs
            if len(questions) > num_pairs:
                questions = questions[:num_pairs]
            if len(answers) > num_pairs:
                answers = answers[:num_pairs]

            # Format the output based on user preference
            if format_output == 'json':
                qa_json = [{'question': questions[i], 'answer': answers[i]} for i in range(len(questions))]
                output = json.dumps(qa_json, indent=2)
            else:  # plain text
                qa_text = "\n".join([f"Q{i+1}: {questions[i]}" for i in range(len(questions))]) + "\n\n"
                qa_text += "\n".join([f"A{i+1}: {answers[i]}" for i in range(len(answers))])
                output = qa_text

            if save_to_file:
                with open(save_to_file, 'w') as file:
                    file.write(output)
                print(f"Output saved to {save_to_file}")

            return output

        except Exception as e:
            attempts += 1
            print(f"Attempt {attempts} failed: {e}")
            if attempts < retry_attempts:
                time.sleep(2)  # Wait before retrying

    return "Failed to generate QA pairs after several attempts."

# Example usage
pdf_path = r"/content/Agentic rag Survey paper.pdf"
num_pairs = 5
format_output = 'json'  # Change to 'json' for JSON output
save_to_file = r"/content/results/Results_text_with_separate_QA.txt"  # Specify the file path to save output

# Extract text from PDF
content = extract_text_from_pdf(pdf_path)

# Generate and print QA pairs
if content:
    qa_pairs_output = generate_qa_pairs(content, num_pairs, format_output, save_to_file=save_to_file)
    print(qa_pairs_output)
else:
    print("No content extracted from PDF.")
# Out:
# Output saved to /content/results/Results_text_with_separate_QA.txt
# [
#   {
#     "question": "What is Retrieval-Augmented Generation (RAG), and what are its limitations?",
#     "answer": "Retrieval-Augmented Generation (RAG) enhances Large Language Models (LLMs) by integrating real-time data retrieval to provide contextually relevant and up-to-date responses.  However, traditional RAG systems are limited by static workflows, a lack of adaptability for multi-step reasoning, and complex task management."
#   },
#   {
#     "question": "How does Agentic RAG improve upon traditional RAG systems?",
#     "answer": "Agentic RAG transcends the limitations of traditional RAG by embedding autonomous AI agents into the RAG pipeline. These agents use agentic design patterns (reflection, planning, tool use, and multi-agent collaboration) to dynamically manage retrieval strategies, refine contextual understanding, and adapt workflows to complex tasks."
#   },
#   {
#     "question": "What are the four key agentic patterns discussed in the survey?",
#     "answer": "The four key agentic patterns are Reflection (iteratively evaluating and refining outputs), Planning (autonomously decomposing complex tasks), Tool Use (interacting with external tools and resources), and Multi-Agent Collaboration (distributing tasks among specialized agents)."
#   },
#   {
#     "question": "What are some applications of Agentic RAG across different industries?",
#     "answer": "Agentic RAG has applications in customer support (personalized responses), healthcare (personalized medicine), legal (contract analysis), finance (risk analysis), education (personalized learning), and creative industries (multimodal content generation)."
#   },
#   {
#     "question": "What tools and frameworks are available for developing Agentic RAG systems?",
#     "answer": "Tools and frameworks for developing Agentic RAG systems include LangChain, LangGraph, LlamaIndex, Hugging Face Transformers, Qdrant, CrewAI, AutoGen, OpenAI Swarm Framework, Agentic RAG with Vertex AI, Amazon Bedrock, IBM Watson, Neo4j, and various vector databases."
#   }
# ]

# %%
import google.generativeai as genai
import fitz
import json
import time
from pathlib import Path
from typing import Union, List, Dict, Optional, Tuple

class QAGenerator:
    """Generates separate questions and answers from PDF content using Gemini model."""

    def __init__(self, model_name: str = 'gemini-1.5-flash'):
        self.model = genai.GenerativeModel(model_name)

    def extract_pdf_text(self, pdf_path: Union[str, Path]) -> str:
        """
        Extracts text from PDF file.

        Args:
            pdf_path: Path to PDF file

        Returns:
            Extracted text content
        """
        try:
            with fitz.open(pdf_path) as doc:
                return " ".join(page.get_text() for page in doc)
        except Exception as e:
            raise IOError(f"PDF extraction failed: {e}")

    def _split_qa(self, text: str) -> Tuple[List[str], List[str]]:
        """
        Splits response into separate questions and answers.

        Args:
            text: Raw response text

        Returns:
            Tuple of question and answer lists
        """
        questions = []
        answers = []

        for line in text.splitlines():
            line = line.strip()
            if line.startswith('Q:'):
                questions.append(line[2:].strip())
            elif line.startswith('A:'):
                answers.append(line[2:].strip())

        return questions, answers

    def generate_qa(
        self,
        content: str,
        num_pairs: int = 3,
        format_output: str = 'plain',
        max_retries: int = 3,
        output_file: Optional[Union[str, Path]] = None
    ) -> Union[str, List[Dict[str, str]]]:
        """
        Generates separated questions and answers from content.

        Args:
            content: Source text
            num_pairs: Number of QA pairs to generate
            format_output: Output format ('plain'/'json')
            max_retries: Maximum retry attempts
            output_file: Optional save path

        Returns:
            QA pairs in requested format
        """
        prompt = f"""Generate {num_pairs} question-answer pairs from this content.
        List all questions first, then list all answers in matching order.
        Format as:
        Q: [Question text]
        Q: [Question text]
        ...
        A: [Answer text]
        A: [Answer text]
        ...

        Content: {content[:8000]}"""  # Limit content length

        for attempt in range(max_retries):
            try:
                # Generate and parse response
                response = self.model.generate_content(prompt)
                questions, answers = self._split_qa(response.text)

                # Validate and trim to requested number
                if len(questions) >= num_pairs and len(answers) >= num_pairs:
                    questions = questions[:num_pairs]
                    answers = answers[:num_pairs]

                    # Format output
                    if format_output == 'json':
                        output = [
                            {'question': q, 'answer': a}
                            for q, a in zip(questions, answers)
                        ]
                    else:
                        q_text = "\n".join(f"Q{i+1}: {q}" for i, q in enumerate(questions))
                        a_text = "\n".join(f"A{i+1}: {a}" for i, a in enumerate(answers))
                        output = f"{q_text}\n\n{a_text}"

                    # Save if requested
                    if output_file:
                        Path(output_file).write_text(
                            json.dumps(output, indent=2) if format_output == 'json' else output
                        )

                    return output

            except Exception as e:
                if attempt == max_retries - 1:
                    raise RuntimeError(f"QA generation failed: {e}")
                time.sleep(2)  # Wait before retry

def main():
    """
    Example usage of QAGenerator with formatted output handling.
    Automatically detects JSON format and prints it with proper indentation.
    """
    generator = QAGenerator()

    try:
        # Extract text from PDF
        content = generator.extract_pdf_text("/content/Agentic rag Survey paper.pdf")

        # Generate QA pairs
        result = generator.generate_qa(
            content=content,
            num_pairs=5,
            format_output='json',
            output_file='qa_output.txt'
        )

        # Format output based on type
        if isinstance(result, (list, dict)):  # JSON output
            print(json.dumps(result, indent=4, ensure_ascii=False))
        else:  # Plain text output
            print(result)

    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# [
#     {
#         "question": "What is the main limitation of Large Language Models (LLMs) addressed by Retrieval-Augmented Generation (RAG)?",
#         "answer": "LLMs rely on static training data, resulting in outdated information, hallucinated responses, and an inability to adapt to dynamic, real-world scenarios.  RAG addresses this by dynamically retrieving real-time information."
#     },
#     {
#         "question": "What are the three core components of a RAG system?",
#         "answer": "The three core components of a RAG system are Retrieval, Augmentation, and Generation."
#     },
#     {
#         "question": "What is Agentic Retrieval-Augmented Generation (Agentic RAG), and how does it improve upon traditional RAG?",
#         "answer": "Agentic RAG integrates autonomous AI agents into the RAG pipeline. This allows for dynamic retrieval strategies, contextual understanding, and iterative refinement, surpassing the limitations of traditional RAG's linear and static design."
#     },
#     {
#         "question": "What are some examples of industries where Agentic RAG has key applications?",
#         "answer": "Healthcare, finance, and education are mentioned as key application areas for Agentic RAG."
#     },
#     {
#         "question": "What are some challenges addressed in the survey regarding Agentic RAG systems?",
#         "answer": "The survey addresses challenges in scaling Agentic RAG systems, ensuring ethical decision-making, and optimizing performance for real-world applications."
#     }
# ]

# %%
# Initialize generator
qa_gen = QAGenerator()

# Generate QA pairs
try:
    content = qa_gen.extract_pdf_text("/content/Agentic rag Survey paper.pdf")
    result = qa_gen.generate_qa(
        content=content,
        num_pairs=3,
        format_output='json',
        output_file='output.txt'
    )
        # Format output based on type
    if isinstance(result, (list, dict)):  # JSON output
            print(json.dumps(result, indent=4, ensure_ascii=False))
    else:  # Plain text output
            print(result)

except Exception as e:
        print(f"Error: {e}")
# Out:
# [
#     {
#         "question": "What is the main limitation of Large Language Models (LLMs) addressed by Retrieval-Augmented Generation (RAG)?",
#         "answer": "The main limitation of LLMs addressed by RAG is their reliance on static pre-training data, resulting in outdated or incomplete responses and an inability to adapt to dynamic, real-world scenarios."
#     },
#     {
#         "question": "What are the three primary components of a RAG system's architecture?",
#         "answer": "The three primary components of a RAG system's architecture are Retrieval, Augmentation, and Generation."
#     },
#     {
#         "question": "What is Agentic Retrieval-Augmented Generation (Agentic RAG), and how does it improve upon traditional RAG?",
#         "answer": "Agentic RAG integrates autonomous AI agents into the RAG pipeline, enabling dynamic retrieval strategies, contextual understanding, and iterative refinement.  This improves upon traditional RAG by providing unparalleled flexibility, scalability, and context-awareness, excelling in complex multi-step reasoning and tasks."
#     }
# ]

# %%
# Initialize generator
qa_gen = QAGenerator()

# Generate QA pairs
try:
    content = qa_gen.extract_pdf_text("/content/Agentic rag Survey paper.pdf")
    result = qa_gen.generate_qa(
        content=content,
        num_pairs=3,
        format_output='plain',
        output_file='output.txt'
    )
        # Format output based on type
    if isinstance(result, (list, dict)):  # JSON output
            print(json.dumps(result, indent=4, ensure_ascii=False))
    else:  # Plain text output
            print(result)

except Exception as e:
        print(f"Error: {e}")
# Out:
# Q1: What is the main limitation of Large Language Models (LLMs) that Retrieval-Augmented Generation (RAG) aims to address?
# Q2: What are the three primary components of a Retrieval-Augmented Generation (RAG) system's architecture?
# Q3: What is Agentic Retrieval-Augmented Generation (Agentic RAG), and how does it improve upon traditional RAG systems?
#
# A1: LLMs rely on static pre-training data, resulting in outdated information, hallucinated responses, and an inability to adapt to dynamic, real-world scenarios.  RAG aims to address this by dynamically retrieving relevant information from external sources.
# A2: The three primary components are Retrieval, Augmentation, and Generation.
# A3: Agentic RAG integrates autonomous AI agents into the RAG pipeline.  This allows for dynamic retrieval strategies, contextual understanding, iterative refinement, and adaptation to complex tasks, surpassing the limitations of traditional RAG's linear and static design.

# %%
#generate QA pairs from text input
import google.generativeai as genai
import json
import time

## Configure API key for Google Generative AI
# apikey=userdata.get('GOOGLE_API_KEY')
# genai.configure(api_key=apikey)

def generate_qa_pairs(text, num_pairs=3, format_output='plain', retry_attempts=3, save_to_file=None):
    """
    Generate question-answer pairs from a text input.

    Parameters:
    - text (str): The text to generate QA pairs from.
    - num_pairs (int): The number of QA pairs to generate.
    - format_output (str): The format for output ('plain' or 'json').
    - retry_attempts (int): Number of retry attempts in case of API failure.
    - save_to_file (str): Path to file where output will be saved.

    Returns:
    - str or dict: The generated QA pairs in the specified format.
    """
    if not isinstance(num_pairs, int) or num_pairs <= 0:
        raise ValueError("num_pairs must be a positive integer.")

    if format_output not in ['plain', 'json']:
        raise ValueError("format_output must be 'plain' or 'json'.")

    attempts = 0
    while attempts < retry_attempts:
        try:
            # Create the GenerativeModel instance
            model = genai.GenerativeModel('gemini-1.5-flash')

            # Generate content with the specified prompt
            prompt = (f"Generate {num_pairs} question-answer pairs from the following text. "
                      f"Provide all questions first and then all answers, separated by new lines. "
                      f"Output in the form Q: question text\nA: answer text\n\nText: {text}")
            response = model.generate_content(prompt)

            # Clean up the generated content
            output = response.text.replace('*', '').replace('#', '')

            # Split the output into questions and answers
            lines = output.split('\n')
            questions = [line.replace('Q:', '').strip() for line in lines if line.startswith('Q:')]
            answers = [line.replace('A:', '').strip() for line in lines if line.startswith('A:')]

            # Ensure the number of questions and answers matches num_pairs
            if len(questions) > num_pairs:
                questions = questions[:num_pairs]
            if len(answers) > num_pairs:
                answers = answers[:num_pairs]

            # Format the output based on user preference
            if format_output == 'json':
                qa_json = [{'question': questions[i], 'answer': answers[i]} for i in range(len(questions))]
                output = json.dumps(qa_json, indent=2)
            else:  # plain text
                qa_text = "\n".join([f"Q{i+1}: {questions[i]}" for i in range(len(questions))]) + "\n\n"
                qa_text += "\n".join([f"A{i+1}: {answers[i]}" for i in range(len(answers))])
                output = qa_text

            if save_to_file:
                with open(save_to_file, 'w') as file:
                    file.write(output)
                print(f"Output saved to {save_to_file}")

            return output

        except Exception as e:
            attempts += 1
            print(f"Attempt {attempts} failed: {e}")
            if attempts < retry_attempts:
                time.sleep(2)  # Wait before retrying

    return "Failed to generate QA pairs after several attempts."

# Example usage
text_input = generated_text
num_pairs = 3
format_output = 'plain'  # Change to 'json' for JSON output
save_to_file = r"/content/results/qa_output.txt"  # Specify the file path to save output

# Generate and print QA pairs
qa_pairs_output = generate_qa_pairs(text_input, num_pairs, format_output, save_to_file=save_to_file)
print(qa_pairs_output)
# Out:
# Output saved to /content/results/qa_output.txt
# Q1: What are the three main types of support documentation provided by Samsung for their microwaves?
# Q2: What are three common issues experienced with Samsung microwaves, and what are the initial troubleshooting steps for each?
# Q3: What information is crucial to provide when contacting Samsung support regarding a microwave issue?
#
# A1: Samsung provides user manuals, online support pages (including FAQs, troubleshooting guides, and how-to videos), and community forums.
# A2: Three common issues are the microwave not heating (check power supply, door interlock, and magnetron), the microwave not turning on (check power supply, control panel lock, and internal fuse), and arcing or sparks inside (check for metal objects, damaged waveguide cover, and food debris).
# A3: When contacting Samsung support, you should provide the model number, serial number, and a detailed description of the problem.

# %%
import google.generativeai as genai
import json
import time
from typing import Union, List, Dict, Optional
from pathlib import Path

class TextQAGenerator:
    """Generates question-answer pairs from text using Gemini model."""

    def __init__(self, model_name: str = 'gemini-1.5-flash'):
        """Initialize with specified model."""
        self.model = genai.GenerativeModel(model_name)

    def _extract_qa_pairs(self, text: str) -> tuple[List[str], List[str]]:
        """
        Extract questions and answers from generated text.

        Args:
            text: Raw generated text

        Returns:
            Tuple of (questions, answers) lists
        """
        questions = []
        answers = []

        for line in text.split('\n'):
            line = line.strip()
            if line.startswith('Q:'):
                questions.append(line[2:].strip())
            elif line.startswith('A:'):
                answers.append(line[2:].strip())

        return questions, answers

    def generate_qa(
        self,
        text: str,
        num_pairs: int = 3,
        format_output: str = 'plain',
        max_retries: int = 3,
        save_path: Optional[Union[str, Path]] = None
    ) -> Union[str, List[Dict[str, str]]]:
        """
        Generate QA pairs from input text.

        Args:
            text: Source text
            num_pairs: Number of QA pairs to generate
            format_output: Output format ('plain'/'json')
            max_retries: Maximum retry attempts
            save_path: Optional path to save results

        Returns:
            Generated QA pairs in requested format

        Raises:
            ValueError: For invalid inputs
            RuntimeError: For generation failures
        """
        # Validate inputs
        if not text.strip():
            raise ValueError("Input text cannot be empty")
        if not isinstance(num_pairs, int) or num_pairs < 1:
            raise ValueError("num_pairs must be positive integer")
        if format_output not in {'plain', 'json'}:
            raise ValueError("format_output must be 'plain' or 'json'")

        prompt = f"""Generate {num_pairs} question-answer pairs from this text.
        List all questions first, then all corresponding answers.
        Format as:
        Q: [Question]
        Q: [Question]
        ...
        A: [Answer to first question]
        A: [Answer to second question]
        ...

        Text: {text[:8000]}"""  # Limit text length for API

        for attempt in range(max_retries):
            try:
                # Generate and parse content
                response = self.model.generate_content(prompt)
                questions, answers = self._extract_qa_pairs(response.text)

                # Validate pairs
                if len(questions) >= num_pairs and len(answers) >= num_pairs:
                    questions = questions[:num_pairs]
                    answers = answers[:num_pairs]

                    # Format output
                    if format_output == 'json':
                        output = [
                            {'question': q, 'answer': a}
                            for q, a in zip(questions, answers)
                        ]
                    else:
                        q_section = "\n".join(f"Q{i+1}: {q}" for i, q in enumerate(questions))
                        a_section = "\n".join(f"A{i+1}: {a}" for i, a in enumerate(answers))
                        output = f"{q_section}\n\n{a_section}"

                    # Save if path provided
                    if save_path:
                        save_path = Path(save_path)
                        save_path.parent.mkdir(parents=True, exist_ok=True)
                        save_path.write_text(
                            json.dumps(output, indent=2) if format_output == 'json'
                            else output
                        )

                    return output

            except Exception as e:
                if attempt == max_retries - 1:
                    raise RuntimeError(f"Failed to generate QA pairs: {str(e)}")
                time.sleep(2)  # Wait before retry

def main():
    """Example usage of TextQAGenerator."""
    # Sample text
    text = """Add your sample text here"""

    generator = TextQAGenerator()

    try:
        # Generate QA pairs
        result = generator.generate_qa(
            text=generated_text,
            num_pairs=5,
            format_output='json',
            save_path='qa_output.txt'
        )

        # Print formatted result
        if isinstance(result, (list, dict)):
            print(json.dumps(result, indent=4, ensure_ascii=False))
        else:
            print(result)

    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# [
#     {
#         "question": "What are the key resources available in Samsung's microwave support documentation?",
#         "answer": "Samsung's support resources include user manuals, online support pages (FAQs, troubleshooting guides, how-to videos, software updates), and community forums."
#     },
#     {
#         "question": "What are some common problems encountered with Samsung microwaves, and what initial troubleshooting steps can be taken for each?",
#         "answer": "Common problems include the microwave not heating (check power supply, door interlock, magnetron, diode, capacitor, control panel), not turning on (check power, control panel lock, internal fuse), arcing/sparks (metal objects, waveguide cover, food debris), turntable not rotating (track, motor), and error codes (check user manual and online support)."
#     },
#     {
#         "question": "What information is crucial when utilizing Samsung's online support resources?",
#         "answer": "Having the model number of your microwave is crucial for accessing specific information online."
#     },
#     {
#         "question": "What should you do if the microwave displays an error code?",
#         "answer": "Consult the user manual or Samsung's online support pages for a description of the error and troubleshooting steps."
#     },
#     {
#         "question": "What information should you have ready when contacting Samsung support directly?",
#         "answer": "When contacting Samsung support, have the model number, serial number, and a clear description of the problem ready."
#     }
# ]
